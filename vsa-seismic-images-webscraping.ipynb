# %% [markdown]
# # Scraping Seismic Images on Virtual Seismic Atlas (VSA)
#
#
# ### Sharing Geosciences Data for a changing world.

# %% [markdown]
# ![VSA](https://i.imgur.com/LuJXwiM.png)

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Problem Statement:
#
# Datasets are essential for all scientists to conduct research, especially coders geoscientists. Research is an inquiry-based process that includes recognising a question, gathering data, analysing and evaluating results, drawing conclusions, and sharing the knowledge gained. The ability to conduct research mainly depends on the datasets. There are massive open-source data available online. However, it is often challenging for students and researchers to navigate the datasets, collect the data and download it. Because mainly data discoverability is poor, documentation is sometimes lacking, and licences can be confusing. I hope with these two projects to add toward the solution of these problems.
#
# I this sense, I have conducted web scraping project:
#
# ##### VSA web scraping:
#
# I have web scraped the Virtual Seismic Atlas (VSA) https://www.seismicatlas.org/ to build a seismic images dataset used in machine learning analysis using a convolution neural network (CNN) to distinguish by faults and folds and discriminate between salt, sedimentary layers, noise and basement.
#
# For more information about the machine learning work, please see our abstract @ https://meetingorganizer.copernicus.org/EGU21/EGU21-6385.html and paper.

# %% [markdown]
# ### Example of Seismic line

# %% [markdown]
# ![Example of Seismic line.png](https://i.imgur.com/rcS9ra2.jpg)

# %% [markdown]
# ### Seismic Interpretation

# %% [markdown]
# Seismic interpretation is the extraction of subsurface geologic information from seismic data.
#
# Reflection seismic data comprise:
# 1. Continuity of reflections indicating geologic structure.
# 2. Variability of reflections indicating stratigraphy, fluids and reservoir fabric.
# 3. The seismic wavelet.
# 4. Noise of various kinds and data defects. Seismic interpretation is the thoughtful procedure of separating these effects.
#
# For more information see: [What Is Seismic Interpretation?](https://explorer.aapg.org/story/articleid/2471/what-is-seismic-interpretation#:~:text=Seismic%20Interpretation%20is%20the%20extraction%20of%20subsurface%20geologic%20information%20from%20seismic%20data.&text=The%20danger%20in%20seismic%20interpretation,of%20reflections%20indicating%20geologic%20structure.) by Satinder Chopra and Alistair R. Brown (May 2013).

# %% [markdown]
# ### A comparison of raw vs interpreted seismic section:

# %% [markdown]
# Architecture and image characteristics of a normal fault - Inner Moray Firth Seismic Interpretation by Rob Butler.

# %% [markdown]
# ![Seismic section](https://i.imgur.com/HvWkyei.jpg)

# %% [markdown]
# These interpretations display a correlation of units across the fault zone - which has synthetic splays and an offset relay structure at depth. The growth strata are chiefly of upper Jurassic in age - with the deepest identified unit par of the middle Jurassic (locally) pre-rift stratigraphy. The annotations identify some "typical" characteristics of faults imaged in 2D seismic data. [Rob Butler, 2015 (VSA)](https://www.seismicatlas.org/entity?id=e5ba8d3c-84e1-4ef7-a154-7788ed483e8f)

# %% [markdown]
# ### Overview:
#
# The web site https://www.seismicatlas.org/ provides a geological interpretation of seismic data and contain a massive number of sesismic sections. In this project, we will retrieve sesimic images to build a dataset with all the related information and seismic imgeas files from this page using web scraping: the process of extracting information from a website in an automated fashion using code. We will use the Python libraries `Requests` (https://pypi.org/project/requests/) and `Beautiful Soup` (https://www.crummy.com/software/BeautifulSoup/bs4/doc/)to scrape data from this page.

# %% [markdown]
# ### VSA:
#
# The VSA is a resource for sharing the geological interpretation of seismic data. By browsing freely through the site you will find seismic images and interpretations. And you can download higher resolution images for your own use - all without signing in. There are no membership fees, all we ask is that you respect the intellectual property rights of the contributors who have posted images on the VSA. Just hit the link "Search" to start!
#
# Use the VSA to find images of subsurface structures, submarine landscapes, the structure of oceanic water-bodies and much more. You can search for analogues of subsurface geology, rapidly contrasting geological features, finding areas of controversy. You'll find results from cutting-edge technology and breaking research alongside historically important images of the subsurface.
#
# The VSA is used by thousands of geoscientists each week. It's a great place to promote your own science, and for companies to showcase datasets and expertise. It's simple to author new content and link to your research webpages or related publications.
#
# [Professor Rob Butler](https://www.abdn.ac.uk/people/rob.butler).

# %% [markdown]
# ### What is web scrabing?
# Web scraping is a term used to describe the use of a program or algorithm to extract and process large amounts of data from the web. Whether you are a data scientist, engineer, or anybody who analyzes large amounts of datasets, the ability to scrape data from the web is a useful skill to have.

# %% [markdown]
# ### Why is python used for scraping?
# Automated web scraping can be a solution to speed up the data collection process. You write your code once and it will get the information you want many times and from many pages. Python is a popular and best programming language for web scraping. Python can handle multiple data crawling or web scraping tasks comfortably. `Requests` and `BeautifulSoup`, are the most famous and widely used Python frameworks.

# %% [markdown]
# ### General project workflow:
# 1. Choose a website and describe the project objective
# 2. Create a list with all the seismic surveys URLs using the charactors from a to z.
# 3. Download the webpage using requests.
# 4. Parse the HTML source code using beautiful soup
# 5. Extract surveys names, information and URLs from page
# 6. Compile extracted information into Python lists and dictionaries
# 7. Extract and combine data from multiple survey pages
# 8. Save the extracted information to a CSV file.

# %% [markdown]
# ### Expected results:
# By the end of the project, we will create a CSV file in the folowing format:

# %% [markdown]
# Title,Data Type,Author,Date,Image url,Description,Info url
# "Crustal Structure, West Orkney Basin, imaged by MOIST",Interpretation,Rob Butler,2021-03-12,https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg,"An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).",https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad
# Deep structure - Outer Isles Fault - from WINCH 1 profile,Interpretation,Rob Butler,2021-03-12,https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg,"An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.",https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139
# "Deep Structure - West Orkney Basin, imaged on ultradeep seismic",Interpretation,Rob Butler,2021-03-12,https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg,"An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and ""W"").",https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a

# %% [markdown]
# ![csv](https://i.imgur.com/PuYWt8O.png)

# %% [markdown]
# ### Runing the code:
# You can execute the code using the "Run" button at the top of this page. You can make changes and save your own version of the naotebook to [Jovian](https://www.jovian,ai) by executing the folowing cells. Then Run-on Binder, or Colab (Google's cloud infrastructure), or Run-on Kaggle.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="seismic-data-processing")
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "ramysaleem/seismic-data-processing" on https://jovian.ai
# [jovian] Uploading notebook..
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.ai/ramysaleem/seismic-data-processing
# 'https://jovian.ai/ramysaleem/seismic-data-processing'

# %% [markdown]
# ## Project Method:

# %% [markdown]
# ### 1. VSA web page detailed  workflow

# %% [markdown]
# 1. The first step of the project is to scrape the VSA Virtual Seismic Atlas https://www.seismicatlas.org/.
#
# 2. Second, we got a list of multiple geological regions that contain all the available seismic data where we selected the (faults) https://www.seismicatlas.org/search?f=1062&s, and (folds) https://www.seismicatlas.org/search?f=1039&s= which contain the seismic images data we are interested in.
#
# 3. Third, we scraped the (Deformation Structures: Faults) website to collect 392 seismic data images.
#
# 4. Later, we got Title, Data Type, Author, Date, Image URL, Description and Info URL from the website.
#
# 5. The (VSA) website contain a search icon that opens the https://www.seismicatlas.org/search?f=&s= web page. This search has multiple filters which contain and hide all the seismic images.
#
# 6. We have used the programmer inspect tool to identify the base URL and attached numbers 1,2,3 to get all the seismic images for each region. After that, we iterate over them to create the 16 pages for the faults images, for example.
#
# 7. From the faults web pages https://www.seismicatlas.org/search?s=faults&pn=0, we start collecting the needed information.
#
# 8. We have created a function to get the section name using the `a' tag.
#
# 9. Another function was implemented to get the images information or label using the `span` tag and `class` "label".
#
# 10. Also, we have created a function that collects the name of the seismic section author and date using the `td` tag.
#
# 11. Moreover, we have collected the images URL using `img` tag and `class` "img-responsive" and get description information using the `p` tag and finally add the URL.
#
# 12. Then, we have created several functions that get all the seismic images information needed.
#
# 13. Additionally, we created several functions using the for loop to pass the pages URL list into the mentioned above functions to return a list.
#
# 14. Finally, we create a function that writes all the info to a CSV file, and later we open it using pandas library as a data frame.

# %% [markdown]
# ### 2. Download the webpage using `requests`

# %% [markdown]
# We installed and imported the requests library to download the web page.
# The library can be installed using `pip`.

# %%
# !pip install requests --upgrade --quiet

# %%
import requests

# %%
url = 'https://seismicatlas.org/search'

# %% [markdown]
# To download a page, we can use the `get` function from requests, which returns a response object.

# %%
response = requests.get(url)

# %% [markdown]
# `requests.get` returns a response object containing the data from the web pae and some other information.
#
# The `.status_code` property can be used to check if the request was successful. Asuccessful response will have [HTTP status code](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes) an between 200 and 299.

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# We can also save it to a file and view the page locally within Jupyter using "file>open".

# %%
with open('webpage.html', 'w') as f:
    f.write(response.text)

# %% [markdown]
# ### 3. Used `Beautiful Soup` to parse the VSA web site and select the web site that contains the different structures

# %% [markdown]
# ## [VSA](https://www.usgs.gov/science-explorer-results?es=3D+Seismic+data&classification=data)

# %% [markdown]
# We have scraped the VSA web main page to Exploring and get the structures web site that has the Seismic images data.

# %% [markdown]
# We installed and imported the `beautifulsoup4` library to parse the web page.
# The library can be installed using `pip`.

# %%
# !pip install beautifulsoup4 --upgrade --quiet

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# Then we parsered the web page and save the out put into a doc, which is a beautiful soup object.

# %%
doc = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# #### 3.1 Image Sections:

# %% [markdown]
# Now let us collect the sections by getting the `div` tag with `class` "content".

# %%
content_div = doc.find('div', class_='content')

# %%
sections = content_div.find_all('section')

# %%
len(sections)
# Out:
# 25

# %%
sections[0]
# Out:
# <section>
# <figure class="thumbnail"><a href="/entity?id=6810547c-3de2-4ece-a840-0158ddbab8f3"><img alt="" class="img-responsive" src="/uploaded/image/200909/0d54ec4a-f3d8-4ffd-99eb-2ad79a66e38d.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=6810547c-3de2-4ece-a840-0158ddbab8f3">FIRE 1 CMP 11 000-20 000</a></span>
# <span class="label label-regional">Regional Project</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td></td>
# </tr>
# <tr>
# <th>Scenes:</th>
# <td>0</td>
# </tr>
# <tr>
# <th>Interpretations:</th>
# <td>1</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2009-09-01</td>
# </tr>
# </tbody></table>
# <p>The southern part of the FIRE profile 1 covers CMPs 11 000-20 000 (c. 275-500 km). The grey scale image is of a migrated section, published in Kukkonen et al. 2006 (see docs &amp; links for publication link).
#
# </p>
# </section>

# %% [markdown]
# Here we have created a function to get the sections that have all the images informations.

# %%
base_url = 'https://seismicatlas.org'

def parse_section(section):
    title = section.find_all('a')[1].text
    data_type = section.find('span', class_='label').text
    description = section.find('p').text.strip()
    url = base_url + section.find('a')['href']
    return {'title': title, 'type': data_type, 'description': description, 'url': url }

# %%
parse_section(sections[0])
# Out:
# {'title': 'FIRE 1 CMP 11 000-20 000',
#  'type': 'Regional Project',
#  'description': 'The southern part of the FIRE profile 1 covers CMPs 11 000-20 000 (c. 275-500 km). The grey scale image is of a migrated section, published in Kukkonen et al. 2006 (see docs & links for publication link).',
#  'url': 'https://seismicatlas.org/entity?id=6810547c-3de2-4ece-a840-0158ddbab8f3'}

# %% [markdown]
# After that we have create a for loop to get all the sections in the page.

# %%
sections_data = [parse_section(section) for section in sections]

# %% [markdown]
# ### 3.2 Sections dataframe using Pandsa

# %% [markdown]
# After we collected all the required information, we have used the `Pandas` library to create a data frame.

# %% [markdown]
# To install the library inside the notbook use `pip` and then `import` to import it as pd for short.

# %% [markdown]
# We have used `Pandas` to create dataframe from the collected data. Then we have import Pandas as pd for short.

# %%
# !pip install Pandas --quiet --upgrade

# %%
import pandas as pd

# %%
sections_df = pd.DataFrame(sections_data)

# %%
sections_df
# Out:
#                                                 title              type  \
# 0                            FIRE 1 CMP 11 000-20 000  Regional Project
# 1                                    Iberseis profile  Regional Project
# 2   Crustal Structure, West Orkney Basin, imaged b...    Interpretation
# 3   Deep structure - Outer Isles Fault - from WINC...    Interpretation
# 4   Deep Structure - West Orkney Basin, imaged on ...    Interpretation
# 5   Deep structure Western Orkney Basin - from GRI...    Interpretation
# 6                             Shallow subsurface MTCs  Regional Project
# 7                                   ESCIN - 2 profile  Regional Project
# 8     Differential vertical movement with mobile salt    Interpretation
# 9                       Salt mobility - imaging flaps    Interpretation
# 10   Reconstructing salt mobility - North Sea example    Interpretation
# 11                       Alcudia deep seismic profile  Regional Project
# 12                               Inversion, North Sea    Interpretation
# 13                 Volcanic geometries - Browse basin    Interpretation
# 14  Interpreting a deepwater thrust system: offsho...             Scene
# 15  Interpreting a deepwater thrust system, offsho...    Interpretation
# 16                                ESCIN - 3.3 profile  Regional Project
# 17           Contourite drift, Western Rockall margin    Interpretation
# 18  Detail of basal surface of two slope channels,...             Scene
# 19  Faults and graben (less VE version), offshore ...    Interpretation
# 20                      Seismic stratigraphy exercise    Interpretation
# 21                       Clinoforms, offshore Morocco             Scene
# 22  Closely spaced faults - and imaging issues, of...    Interpretation
# 23                                  ESCIN - 1 profile  Regional Project
# 24                                ESCIN - 3.2 profile  Regional Project
#
#                                           description  \
# 0   The southern part of the FIRE profile 1 covers...
# 1   A deep seismic profile through part of souther...
# 2   An interpretation of the first profile acquire...
# 3   An interpretation of BIRPS' WINCH-1 profile (f...
# 4   An interpretation of the BIRPS DRUM line (from...
# 5   Interpretation of the GRID 17 profile (aka Syn...
# 6   Variance extraction coloured by subsurface ele...
# 7          Deep seismic profile from northern Iberia.
# 8   Annotated interpretation of stratigraphic rela...
# 9   An annotated interpretation, for discussion in...
# 10  Annotated interpretation, used for discussion ...
# 11  The Alcudia deep seismic reflection profile, t...
# 12  An interpretation of an inversion structure fr...
# 13  An interpretation of the volcanic bodies image...
# 14  This image can be used as a simple interpretat...
# 15  An interpretation of a deepwater thrust belt. ...
# 16  A deep seismic profile through part of norther...
# 17  A contourite drift, showing internal architect...
# 18  This is a 3D view of the basal surface of two ...
# 19  A rather better representation of faults and g...
# 20  Correction of a seismic interpretation exercis...
# 21  Detail of clinoforms seen at the shelf-break, ...
# 22  This and associated interpretation (annotated)...
# 23         Deep seismic profile from northern Iberia.
# 24  A deep seismic profile through part of norther...
#
#                                                   url
# 0   https://seismicatlas.org/entity?id=6810547c-3d...
# 1   https://seismicatlas.org/entity?id=0ba1b701-af...
# 2   https://seismicatlas.org/entity?id=cad7a17f-d9...
# 3   https://seismicatlas.org/entity?id=5daf55c7-7d...
# 4   https://seismicatlas.org/entity?id=92b4fd80-b1...
# 5   https://seismicatlas.org/entity?id=d89526c0-b2...
# 6   https://seismicatlas.org/entity?id=3117237a-35...
# 7   https://seismicatlas.org/entity?id=a8895dfe-08...
# 8   https://seismicatlas.org/entity?id=4b096fa8-2d...
# 9   https://seismicatlas.org/entity?id=ca5d068a-92...
# 10  https://seismicatlas.org/entity?id=10da4247-fe...
# 11  https://seismicatlas.org/entity?id=cc5069a7-37...
# 12  https://seismicatlas.org/entity?id=7998e3da-2a...
# 13  https://seismicatlas.org/entity?id=fafcce6a-4f...
# 14  https://seismicatlas.org/entity?id=32f3fa41-a5...
# 15  https://seismicatlas.org/entity?id=ed086012-c8...
# 16  https://seismicatlas.org/entity?id=91beb115-13...
# 17  https://seismicatlas.org/entity?id=1451ffa5-90...
# 18  https://seismicatlas.org/entity?id=2bec6726-d1...
# 19  https://seismicatlas.org/entity?id=c56c95c3-d8...
# 20  https://seismicatlas.org/entity?id=ba4bfcdc-55...
# 21  https://seismicatlas.org/entity?id=785ad85a-ef...
# 22  https://seismicatlas.org/entity?id=6157758c-05...
# 23  https://seismicatlas.org/entity?id=dabf42ff-93...
# 24  https://seismicatlas.org/entity?id=ed912b92-82...

# %% [markdown]
# ### 3.3 VSA web pages CSV file

# %% [markdown]
# We have Created CSV file(s) with the extracted information to store the data

# %%
sections_df.to_csv('projects.csv', index=None)

# %%
# !head projects.csv
# Out:
# title,type,description,url
# FIRE 1 CMP 11 000-20 000,Regional Project,"The southern part of the FIRE profile 1 covers CMPs 11 000-20 000 (c. 275-500 km). The grey scale image is of a migrated section, published in Kukkonen et al. 2006 (see docs & links for publication link).",https://seismicatlas.org/entity?id=6810547c-3de2-4ece-a840-0158ddbab8f3
# Iberseis profile,Regional Project,A deep seismic profile through part of southern Iberia.,https://seismicatlas.org/entity?id=0ba1b701-afd8-4511-be51-7bc88034a0d7
# "Crustal Structure, West Orkney Basin, imaged by MOIST",Interpretation,"An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).",https://seismicatlas.org/entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad
# Deep structure - Outer Isles Fault - from WINCH 1 profile,Interpretation,"An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.",https://seismicatlas.org/entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139
# "Deep Structure - West Orkney Basin, imaged on ultradeep seismic",Interpretation,"An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and ""W"").",https://seismicatlas.org/entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a
# Deep structure Western Orkney Basin - from GRID17 (SLAVE),Interpretation,"Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, ""W"")",https://seismicatlas.org/entity?id=d89526c0-b276-4815-98fb-e2f99515195f
# Shallow subsurface MTCs,Regional Project,Variance extraction coloured by subsurface elevation at the composite basal shear surface of shallow subsurface MTCs. The point values correspond to subsurface elevation. The MTC is continuous across a gorge between two anticlines. A more detailed explanation can be found in Ortiz-Karpf et al (2015). The link to the paper can be found in the docs and links tab.,https://seismicatlas.org/entity?id=3117237a-35fd-4a2a-b506-fbbae76a4a7e
# ESCIN - 2 profile,Regional Project,Deep seismic profile from northern Iberia.,https://seismicatlas.org/entity?id=a8895dfe-081e-4926-a616-37ae8f556ece
# Differential vertical movement with mobile salt,Interpretation,"Annotated interpretation of stratigraphic relationships associated with salt mobility, for reconstructing the history of differential vertical movement - in a seismic interpretation course.",https://seismicatlas.org/entity?id=4b096fa8-2dff-46b2-8038-ed36aa22fba5

# %%
# Execute this to save new versions of the notebook

jovian.commit(project="seismic-data-processing")
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "ramysaleem/seismic-data-processing" on https://jovian.ai
# [jovian] Uploading notebook..
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.ai/ramysaleem/seismic-data-processing
# 'https://jovian.ai/ramysaleem/seismic-data-processing'

# %% [markdown]
# # 4. Getting faults seismic interpretation images information

# %% [markdown]
# ![faults](https://i.imgur.com/ZgwoXy0.jpg)

# %% [markdown]
# Let now get the info about faults interpretations by adding the "?f=1003&s&pn=" to the base URL.

# %%
fault_page_url = url + '?f=1003&s&pn='
fault_page_url
# Out:
# 'https://seismicatlas.org/search?f=1003&s&pn='

# %% [markdown]
# The faults data in VSA have 392 data interpreted as faults. This data stored in 16 pages, numbered from 0 to 15. Now let us create a list of all the faults web pages.

# %%
faults_url = []

for i in range(0, 16):
    faults_url.append(fault_page_url + str(i))

print(faults_url)
# Out:
# ['https://seismicatlas.org/search?f=1003&s&pn=0', 'https://seismicatlas.org/search?f=1003&s&pn=1', 'https://seismicatlas.org/search?f=1003&s&pn=2', 'https://seismicatlas.org/search?f=1003&s&pn=3', 'https://seismicatlas.org/search?f=1003&s&pn=4', 'https://seismicatlas.org/search?f=1003&s&pn=5', 'https://seismicatlas.org/search?f=1003&s&pn=6', 'https://seismicatlas.org/search?f=1003&s&pn=7', 'https://seismicatlas.org/search?f=1003&s&pn=8', 'https://seismicatlas.org/search?f=1003&s&pn=9', 'https://seismicatlas.org/search?f=1003&s&pn=10', 'https://seismicatlas.org/search?f=1003&s&pn=11', 'https://seismicatlas.org/search?f=1003&s&pn=12', 'https://seismicatlas.org/search?f=1003&s&pn=13', 'https://seismicatlas.org/search?f=1003&s&pn=14', 'https://seismicatlas.org/search?f=1003&s&pn=15']

# %%
faults_url
# Out:
# ['https://seismicatlas.org/search?f=1003&s&pn=0',
#  'https://seismicatlas.org/search?f=1003&s&pn=1',
#  'https://seismicatlas.org/search?f=1003&s&pn=2',
#  'https://seismicatlas.org/search?f=1003&s&pn=3',
#  'https://seismicatlas.org/search?f=1003&s&pn=4',
#  'https://seismicatlas.org/search?f=1003&s&pn=5',
#  'https://seismicatlas.org/search?f=1003&s&pn=6',
#  'https://seismicatlas.org/search?f=1003&s&pn=7',
#  'https://seismicatlas.org/search?f=1003&s&pn=8',
#  'https://seismicatlas.org/search?f=1003&s&pn=9',
#  'https://seismicatlas.org/search?f=1003&s&pn=10',
#  'https://seismicatlas.org/search?f=1003&s&pn=11',
#  'https://seismicatlas.org/search?f=1003&s&pn=12',
#  'https://seismicatlas.org/search?f=1003&s&pn=13',
#  'https://seismicatlas.org/search?f=1003&s&pn=14',
#  'https://seismicatlas.org/search?f=1003&s&pn=15']

# %% [markdown]
# ### 4.1 Fults images information

# %% [markdown]
# ![faults on seimsic interpretation](https://i.imgur.com/sAIwuw6.jpg)

# %% [markdown]
# Lets get the information from the collected faults images

# %%
faults_url_1 = faults_url[0]
faults_url_1
# Out:
# 'https://seismicatlas.org/search?f=1003&s&pn=0'

# %%
f_responses_1 = requests.get(faults_url_1)
f_responses_1
# Out:
# <Response [200]>

# %%
f_responses_1.text[:1000]
# Out:
# '<!DOCTYPE html>\n\n<html>\n<head>\n    <meta charset="utf-8" />\n    <title>VSA - Search</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible" />\n    <meta content="width=device-width, initial-scale=1" name="viewport" />\n    \n    <link href="/resources/css/bootstrap.min.css" media="screen" rel="stylesheet" />\n\t<link href="/resources/css/bootstrap-theme.min.css" media="screen" rel="stylesheet" />\n\t<link href="/resources/css/theme.css" media="screen" rel="stylesheet" />\n\t    \n    <script src="../../../resources/js/modernizr.min.js"></script>\n    <!--[if lt IE 9]>\n    <script src="../../../resources/js/respond.min.js" th:src="@{/resources/js/respond.min.js}"></script>\n    <![endif]-->\n</head>\n<body>\n\t\n\t<header>\n\t\t<div class="container" role="header">\n\n\t\t\t<div class="row">\n\t\t\t\t<div class="col-sm-6">\n\t\t\t\t\t<div class="logo">\n\t\t\t\t\t\t<a class="nohover" href="/"><img alt="" height="50" width="143" src="/resources/css/vsa-logo.png" />\n\t\t\t\t\t\t\t<h3>Virtual Seismic Atlas</h3>\n\t\t\t\t\t\t\t<p>Sharing '

# %%
len(f_responses_1.text)
# Out:
# 75968

# %%
faults_url_data_1 = f_responses_1.text

# %%
with open('first_faults_data_page.html', 'w') as f:
    f.write(faults_url_data_1)

# %%
doc_faults_1 = BeautifulSoup(faults_url_data_1, 'html.parser')
doc_faults_1
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>VSA - Search</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/resources/css/bootstrap.min.css" media="screen" rel="stylesheet"/>
# <link href="/resources/css/bootstrap-theme.min.css" media="screen" rel="stylesheet"/>
# <link href="/resources/css/theme.css" media="screen" rel="stylesheet"/>
# <script src="../../../resources/js/modernizr.min.js"></script>
# <!--[if lt IE 9]>
#     <script src="../../../resources/js/respond.min.js" th:src="@{/resources/js/respond.min.js}"></script>
#     <![endif]-->
# </head>
# <body>
# <header>
# <div class="container" role="header">
# <div class="row">
# <div class="col-sm-6">
# <div class="logo">
# <a class="nohover" href="/"><img alt="" height="50" src="/resources/css/vsa-logo.png" width="143"/>
# <h3>Virtual Seismic Atlas</h3>
# <p>Sharing the geological interpretation of seismic data</p>
# </a>
# </div>
# </div>
# <div class="col-sm-6">
# <form action="/search" class="navbar-form navbar-right" method="get" role="search">
# <div class="form-group">
# <input class="form-control" name="s" placeholder="Search" type="text"/>
# </div>
# <button class="btn btn-default hidden-xs" type="submit">
# <span class="glyphicon glyphicon-search"></span>
# </button>
# </form>
# </div>
# </div>
# <div class="row">
# <div class="col-sm-12 profile-links">
# <a href="/login">Log in</a>
# </div>
# </div>
# <div class="row">
# <div class="col-sm-12">
# <ul class="main-navigation nav nav-tabs navbar-right">
# <li class="active"><a href="/search?nav=reset"><span class="glyphicon glyphicon-search"></span><br/>Search</a></li>
# <li><a href="/about"><span class="glyphicon glyphicon-info-sign"></span><br/>About</a></li>
# <li><a href="/sponsorship"><span class="glyphicon glyphicon-gift"></span><br/>Sponsorship</a></li>
# <li><a href="/news"><span class="glyphicon glyphicon-bullhorn"></span><br/>What's new</a></li>
# <li><a href="/help"><span class="glyphicon glyphicon-question-sign"></span><br/>Help</a></li>
# </ul>
# </div>
# </div>
# </div>
# </header>
# <div class="container main" role="main">
# <div class="row">
# <div class="col-xs-3">
# <div class="faceted-nav-panel">
# <!-- form>
#                 <div class="checkbox">
#                   <label>
#                     <input type="checkbox"> Include Related Documents
#                   </label>
#                 </div>
#               </form -->
# <div class="text-center">
# <a class="action-node-toggle" data-toggle="true" href="#">Expand All</a>
#                 |
#                 <a class="action-node-toggle" data-toggle="false" href="#">Collapse All</a>
# </div>
# <section>
# <h4>Geological Interpretation</h4>
# <ul>
# <li class="expanded">
# <a class="link-cursor-pointer">Deformation Structures</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1036&amp;s=">Inversions</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1036&amp;s=">(44)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1031&amp;s=">Linkages</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1031&amp;s=">(103)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1012&amp;s=">Normal Faults</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1012&amp;s=">(176)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1024&amp;s=">Secondary Faults</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1024&amp;s=">(45)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1019&amp;s=">Strike-Slip Faults</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1019&amp;s=">(37)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1004&amp;s=">Thrusts</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1004&amp;s=">(172)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Tectonostratigraphic Style</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1062&amp;s=">Fault Scarps</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1062&amp;s=">(17)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1057&amp;s=">Growth Strata</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1057&amp;s=">(103)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1058&amp;s=">Post-tectonic</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1058&amp;s=">(107)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1060&amp;s=">Pre-tectonic</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1060&amp;s=">(106)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1059&amp;s=">Syn-tectonic</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1059&amp;s=">(112)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Seismic Stratigraphy</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1064&amp;s=">Downlap</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1064&amp;s=">(19)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1065&amp;s=">Erosional truncation</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1065&amp;s=">(41)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1066&amp;s=">Onlap</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1066&amp;s=">(113)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1067&amp;s=">Toplap</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1067&amp;s=">(13)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Depositional Architecture</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1073&amp;s=">Linear and Sinuous Features</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1073&amp;s=">(18)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1069&amp;s=">Lumps and Bumps</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1069&amp;s=">(3)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1079&amp;s=">Sheets and Surfaces</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1079&amp;s=">(73)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1085&amp;s=">Volumes</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1085&amp;s=">(22)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Depositional Environment</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1098&amp;s=">Coastal Environment</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1098&amp;s=">(2)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1093&amp;s=">Continental Environment</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1093&amp;s=">(2)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1104&amp;s=">Marine Environment</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1104&amp;s=">(129)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Depositional Processes</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1113&amp;s=">BioConstructional</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1113&amp;s=">(1)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1116&amp;s=">Fall-out</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1116&amp;s=">(16)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1128&amp;s=">Glacial</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1128&amp;s=">(1)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1119,1003&amp;s=">Gravity flows</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1119,1003&amp;s=">(84)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1122&amp;s=">Shear Flows</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1122&amp;s=">(6)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Sediment Composition</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1137&amp;s=">Carbonates</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1137&amp;s=">(6)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1138,1003&amp;s=">Evaporites</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1138,1003&amp;s=">(12)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1136&amp;s=">Siliciclastics</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1136&amp;s=">(96)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Diagenesis / Fluids</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1142&amp;s=">DHIs</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1142&amp;s=">(5)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1141&amp;s=">Gas hydrates</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1141&amp;s=">(7)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1140&amp;s=">Opal A - CT</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1140&amp;s=">(3)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Igneous Features</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1149&amp;s=">Extrusive</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1149&amp;s=">(7)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1144&amp;s=">Intrusive</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1144&amp;s=">(12)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Basement</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1155&amp;s=">Crust Type</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1155&amp;s=">(69)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1154&amp;s=">Moho</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1154&amp;s=">(39)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Age of Strata</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1162&amp;s=">Cenozoic</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1162&amp;s=">(197)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1204,1003&amp;s=">Mesozoic</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1204,1003&amp;s=">(121)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1246&amp;s=">Paleozoic</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1246&amp;s=">(38)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Age of Deformation</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1307,1003&amp;s=">Cenozoic</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1307,1003&amp;s=">(117)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1349&amp;s=">Mesozoic</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1349&amp;s=">(61)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1391&amp;s=">Paleozoic</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1391&amp;s=">(11)</a></li>
# </ul>
# </li>
# </ul>
# <h4>Geological Context</h4>
# <ul>
# <li>
# <a class="link-cursor-pointer">Plate Settings and Margins</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1465&amp;s=">Continental Margins</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1465&amp;s=">(197)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1456&amp;s=">Convergent</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1456&amp;s=">(81)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1453&amp;s=">Divergent (constructive)</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1453&amp;s=">(11)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1462&amp;s=">Intraplate</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1462&amp;s=">(58)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1459&amp;s=">Transform</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1459&amp;s=">(8)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Tectonics</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1478&amp;s=">Non-Plate driven</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1478&amp;s=">(170)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1470&amp;s=">Plate-driven</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1470&amp;s=">(199)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Basin Setting</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1488,1003&amp;s=">Continental Rifts</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1488,1003&amp;s=">(102)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1489&amp;s=">Continental Sags</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1489&amp;s=">(11)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1490&amp;s=">Continental Terraces and Rises</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1490&amp;s=">(19)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1491&amp;s=">Forearc</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1491&amp;s=">(4)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1492&amp;s=">Foredeeps</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1492&amp;s=">(16)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1493&amp;s=">Foreland</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1493&amp;s=">(11)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1494&amp;s=">Intermontane/Retromontane</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1494&amp;s=">(22)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1495&amp;s=">Intra- and Back-arc</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1495&amp;s=">(3)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1497&amp;s=">Oceans</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1497&amp;s=">(2)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1499&amp;s=">Passive Margin</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1499&amp;s=">(165)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1500&amp;s=">Remnant Ocean</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1500&amp;s=">(7)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1501&amp;s=">Subduction Accretion</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1501&amp;s=">(23)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1502&amp;s=">Trench-Trench-Slope</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1502&amp;s=">(15)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1503&amp;s=">Wrench Systems</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1503&amp;s=">(11)</a></li>
# </ul>
# </li>
# </ul>
# <h4>Geographic Context</h4>
# <ul>
# <li>
# <a class="link-cursor-pointer">Physical Geography</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1526&amp;s=">Continents</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1526&amp;s=">(48)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1506&amp;s=">Oceans</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1506&amp;s=">(306)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Political Geography</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1539,1003&amp;s=">Africa</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1539,1003&amp;s=">(126)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1603&amp;s=">Asia</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1603&amp;s=">(24)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1750&amp;s=">Australia-Oceana</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1750&amp;s=">(11)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1658&amp;s=">Europe</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1658&amp;s=">(184)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1710&amp;s=">North America</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1710&amp;s=">(19)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1777&amp;s=">South America</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1777&amp;s=">(16)</a></li>
# </ul>
# </li>
# </ul>
# <h4>Seismic Oceanography</h4>
# <ul>
# <li>
# <a class="link-cursor-pointer">Oceans</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1795&amp;s=">S Atlantic</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1795&amp;s=">(1)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Processes</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1805&amp;s=">Along Slope Flows</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1805&amp;s=">(1)</a></li>
# </ul>
# </li>
# </ul>
# <h4>Geophysics</h4>
# <ul>
# <li>
# <a class="link-cursor-pointer">Survey Information</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1835&amp;s=">Acquisition History</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1835&amp;s=">(3)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1817&amp;s=">Environment</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1817&amp;s=">(288)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1828&amp;s=">Max Two-Way Time</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1828&amp;s=">(130)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1843,1003&amp;s=">Migrated</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1843,1003&amp;s=">(136)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1840&amp;s=">Polarity</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1840&amp;s=">(3)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1822&amp;s=">Type</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1822&amp;s=">(284)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1837&amp;s=">Wavelet</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1837&amp;s=">(26)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1844&amp;s=">Well Ties</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1844&amp;s=">(26)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Data Presentation</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1849&amp;s=">Display</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1849&amp;s=">(155)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1847&amp;s=">Vertical Scale - Depth</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1847&amp;s=">(22)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1848&amp;s=">Vertical Scale - Time</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1848&amp;s=">(270)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Image Type</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1860&amp;s=">Cube/Composite</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1860&amp;s=">(50)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1859,1003&amp;s=">Horizon/Surface Map</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1859,1003&amp;s=">(30)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1858&amp;s=">Time/Depth Slice</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1858&amp;s=">(4)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1857&amp;s=">Vertical Profile</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,1857&amp;s=">(255)</a></li>
# </ul>
# </li>
# </ul>
# <h4>Other</h4>
# <ul>
# <li>
# <a class="link-cursor-pointer">Created / Modified</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2008&amp;s=">2008</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2008&amp;s=">(130)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2009&amp;s=">2009</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2009&amp;s=">(56)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=D-2010,1003&amp;s=">2010</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=D-2010,1003&amp;s=">(82)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2011&amp;s=">2011</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2011&amp;s=">(17)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2012&amp;s=">2012</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2012&amp;s=">(6)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2013&amp;s=">2013</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2013&amp;s=">(12)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2014&amp;s=">2014</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2014&amp;s=">(25)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2015&amp;s=">2015</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2015&amp;s=">(7)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2016&amp;s=">2016</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2016&amp;s=">(14)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2017&amp;s=">2017</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2017&amp;s=">(1)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2019&amp;s=">2019</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2019&amp;s=">(5)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2020&amp;s=">2020</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2020&amp;s=">(5)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2021&amp;s=">2021</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,D-2021&amp;s=">(32)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Type</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,INTERPRETATION&amp;s=">Interpretation</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,INTERPRETATION&amp;s=">(266)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,REGIONAL_PROJECT&amp;s=">Regional Project</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,REGIONAL_PROJECT&amp;s=">(66)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=SCENE,1003&amp;s=">Scene</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=SCENE,1003&amp;s=">(60)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">Interpretation Count</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,I-0&amp;s=">0</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,I-0&amp;s=">(93)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,I-1&amp;s=">1</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,I-1&amp;s=">(20)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,I-2-5&amp;s=">2-5</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,I-2-5&amp;s=">(13)</a></li>
# </ul>
# </li>
# <li>
# <a class="link-cursor-pointer">VSA Author</a>
# <ul>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,A-Rob%20Butler&amp;s=">Rob Butler</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,A-Rob%20Butler&amp;s=">(143)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,A-Taija%20Torvela&amp;s=">Taija Torvela</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,A-Taija%20Torvela&amp;s=">(32)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,A-Chris%20Jackson&amp;s=">Chris Jackson</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,A-Chris%20Jackson&amp;s=">(20)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,A-Jean-Louis%20Grimaud&amp;s=">Jean-Louis Grimaud</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,A-Jean-Louis%20Grimaud&amp;s=">(20)</a></li>
# <li><a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=1003,A-Simon%20Stewart&amp;s=">Simon Stewart</a><a class="count" href="https://seismicatlas.org/search?pn=0&amp;f=1003,A-Simon%20Stewart&amp;s=">(18)</a></li>
# </ul>
# </li>
# </ul>
# </section>
# </div>
# </div>
# <div class="col-xs-9 content">
# <div class="facet-label">
# <a class="btn btn-xxxs btn-danger" href="https://seismicatlas.org/search?pn=0&amp;f=&amp;s="><span class="glyphicon glyphicon-remove"></span></a>
# <span>Deformation Structures:</span>
# <a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=&amp;s=" title="Click to Remove">Faults</a>
# </div>
# <small>Use the options on the left to narrow your search further, or to widen your search, you can remove previous selections from the list above.</small>
# <br/>
# <br/><br/>
# <form action="" class="pagination-heading" method="get" role="form">
# <input name="f" type="hidden" value="1003"/>
# <input name="pn" type="hidden" value="0"/>
# <div class="row">
# <div class="col-md-3 col-sm-6 nowrap">
# <div class="form-group">
# <p class="form-control-static"><b>Results: 1-25 of 392</b></p>
# </div>
# </div>
# <div class="col-md-3 col-sm-6 pull-right">
# <div class="pull-right">
# <div class="btn-group">
# <button class="btn btn-default btn-sm dropdown-toggle" data-toggle="dropdown" type="button">
#                         Display settings
#                         <span class="caret"></span>
# </button>
# <div class="dropdown-menu dropdown-menu-right" role="menu" style="">
# <br/>
# <div class="form-horizontal" style="width: 300px; padding: 20px;">
# <div class="form-group">
# <label class="col-xs-6" for="input_sort_by">Sort by:</label>
# <div class="col-xs-6">
# <select class="form-control input-sm" id="input_sort_by" name="sb">
# <option value="relevance">Relevance</option>
# <option value="name">Display Name</option>
# <option selected="selected" value="date">Date Modified</option>
# </select>
# </div>
# </div>
# <div class="form-group">
# <label class="col-xs-6" for="input_sort_order">Sort order:</label>
# <div class="col-xs-6">
# <select class="form-control input-sm" id="input_sort_order" name="so">
# <option value="asc">Ascending</option>
# <option selected="selected" value="desc">Descending</option>
# </select>
# </div>
# </div>
# <div class="form-group">
# <label class="col-xs-6" for="input_items_per_page">Items per page:</label>
# <div class="col-xs-6">
# <select class="form-control input-sm" id="input_items_per_page" name="ps">
# <option value="10">10</option>
# <option selected="selected" value="25">25</option>
# <option value="50">50</option>
# </select>
# </div>
# </div>
# <div class="form-group">
# <div class="col-xs-offset-2 col-xs-8 text-center">
# <button class="btn btn-default btn-xs" type="submit"><span class="glyphicon glyphicon-ok"></span> Apply</button>
# <button class="btn btn-default btn-xs" type="reset"><span class="glyphicon glyphicon-remove"></span> Cancel</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-6 col-sm-12 text-right nowrap">
# <ul class="pager">
# <li><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=0"><span class="glyphicon icon-first"></span></a></li>
# <li class="active" href="#"><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=0">1</a></li>
# <li href="#"><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=1">2</a></li>
# <li href="#"><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=2">3</a></li>
# <li href="#"><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=3">4</a></li>
# <li href="#"><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=4">5</a></li>
# <li><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=1">Next <span class="glyphicon icon-next"></span></a></li>
# <li><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=15"><span class="glyphicon icon-last"></span></a></li>
# </ul>
# </div>
# </div>
# </form>
# <section>
# <figure class="thumbnail"><a href="/entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad"><img alt="" class="img-responsive" src="/uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad">Crustal Structure, West Orkney Basin, imaged by MOIST</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-03-12</td>
# </tr>
# </tbody></table>
# <p>An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17). </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139"><img alt="" class="img-responsive" src="/uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139">Deep structure - Outer Isles Fault - from WINCH 1 profile</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-03-12</td>
# </tr>
# </tbody></table>
# <p>An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a"><img alt="" class="img-responsive" src="/uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a">Deep Structure - West Orkney Basin, imaged on ultradeep seismic</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-03-12</td>
# </tr>
# </tbody></table>
# <p>An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W"). </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=d89526c0-b276-4815-98fb-e2f99515195f"><img alt="" class="img-responsive" src="/uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=d89526c0-b276-4815-98fb-e2f99515195f">Deep structure Western Orkney Basin - from GRID17 (SLAVE)</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-03-12</td>
# </tr>
# </tbody></table>
# <p>Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=7998e3da-2a89-4835-8809-e659078811aa"><img alt="" class="img-responsive" src="/uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=7998e3da-2a89-4835-8809-e659078811aa">Inversion, North Sea</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-19</td>
# </tr>
# </tbody></table>
# <p>An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0"><img alt="" class="img-responsive" src="/uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0">Interpreting a deepwater thrust system, offshore Namibia</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-18</td>
# </tr>
# </tbody></table>
# <p>An interpretation of a deepwater thrust belt. See associated scene if you'd like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=c56c95c3-d872-4b51-88c1-0f05d39effeb"><img alt="" class="img-responsive" src="/uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=c56c95c3-d872-4b51-88c1-0f05d39effeb">Faults and graben (less VE version), offshore Tunisia</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-06</td>
# </tr>
# </tbody></table>
# <p>A rather better representation of faults and graben structure, with less vertical exaggeration. See the alternate interpretation for comparison. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=ba4bfcdc-5596-45a2-a320-88622c9f49b3"><img alt="" class="img-responsive" src="/uploaded/image/201309/21916a9a-2153-4ed2-9d89-5d005f5bdea5.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=ba4bfcdc-5596-45a2-a320-88622c9f49b3">Seismic stratigraphy exercise</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Julien Moreau</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2013-09-12</td>
# </tr>
# </tbody></table>
# <p>Correction of a seismic interpretation exercise I gave.
# The interpretation is uniquely based on reflection termination picking which indicate bounding surfaces. No model is involved.
# Colours between two successive bounding surfaces have no genetic meaning they only give a sort of chronology through the repetition of a colour cycle (blue, pink, green,yellow) .
# The objective of the exer...</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=6157758c-059b-4efd-995b-1f0058a2473f"><img alt="" class="img-responsive" src="/uploaded/image/202102/aec6418e-052c-4295-b65c-b8c7e610ff7a.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=6157758c-059b-4efd-995b-1f0058a2473f">Closely spaced faults - and imaging issues, offshore NW Morocco</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>This and associated interpretation (annotated) shows array of "synthetic" normal faults offsetting high-frequrency reflectors (probable contourites). </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=8f3d5439-6dc2-4c68-9664-e6839b496277"><img alt="" class="img-responsive" src="/uploaded/image/200908/4be2aa3a-a452-4bc0-bc90-f4e6524370a9.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=8f3d5439-6dc2-4c68-9664-e6839b496277">A high resolution version of the thrust belt, Namibia</a></span>
# <span class="label label-scene">Scene</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Interpretations:</th>
# <td>0</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2009-08-17</td>
# </tr>
# </tbody></table>
# <p>High quality seismic reflection data reveal thrust and fold structural geometry offshore Namibia. The lack of image distortion and amplitude variations associated with structures indicates a generally simple seismic velocity structure that is a function of depth rather than stratigraphy. Note the preservation of amplitude up to the thrust cut-offs, with almost no loss in data quality....</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=922c7210-5e4a-4945-8bea-8fa95574364b"><img alt="" class="img-responsive" src="/uploaded/image/202001/462e8987-c4d2-493c-b77e-c60c0be9dd62.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=922c7210-5e4a-4945-8bea-8fa95574364b">The Moray Firth exercise interp annotated </a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2020-01-20</td>
# </tr>
# </tbody></table>
# <p>This is the annotated version - with labelled megasequences and selected structures. Note that the boxed area (R side) is considered to have a high uncertainty - stemming from problems correlating stratal reflectors which are rather discontinuous here. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=b047b8a3-26ff-4198-ba0c-ea8fb418c524"><img alt="" class="img-responsive" src="/uploaded/image/202102/42954b88-dd40-49db-9621-f324257078f6.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=b047b8a3-26ff-4198-ba0c-ea8fb418c524">Interpretation solution to exercise - profile 29. </a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Interpretation (solution) to interpretation exercise (see clean image). The DOCS AND LINKS HERE has a step-wise pdf solution. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=055c90aa-f84c-449a-8f25-ca6581235e7d"><img alt="" class="img-responsive" src="/uploaded/image/202102/704bc1b9-0922-4556-9e8f-92ce870076a3.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=055c90aa-f84c-449a-8f25-ca6581235e7d">Faults and graben structure, offshore Tunisia</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-06</td>
# </tr>
# </tbody></table>
# <p>This interpretation shows faults continuing to depth. The fault geometries on the right are obscured by migration and fault-shadowing artifacts. Note the scale - interpretation (less VE) version gives a more "realistic representation of basin structure. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=45825358-bfaa-41b9-aa4d-20d413d7ffcd"><img alt="" class="img-responsive" src="/uploaded/image/202102/10317df6-a715-4a48-b4e6-bc3e9e67d060.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=45825358-bfaa-41b9-aa4d-20d413d7ffcd">Imaging issues on the Apulian fault</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Apulian fault scarp - the seabed expression of a normal fault. The interpretation shows the image distortions that result - with dimming a migration problems in both the hangingwall and footwall. The image has very high (&gt; x5) vertical exaggeration of the seabed. See the alternate interpretation for a more realistic display. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=f6c7b5b1-f344-4b95-b1a7-8032e50e8dba"><img alt="" class="img-responsive" src="/uploaded/image/202102/e9a2f32e-be00-4448-bd67-d94ecae41727.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=f6c7b5b1-f344-4b95-b1a7-8032e50e8dba">Faults in shallow section of the Inner Moray Firth</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>An interpretation of faults and stratal reflectors. The clean version is set up as an interpretation exercise.</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=0ccd2827-2d7e-4d65-8f65-dc1dba410ccc"><img alt="" class="img-responsive" src="/uploaded/image/202102/a2649f5d-bdb4-4d8a-94ca-d0b79e9d9421.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=0ccd2827-2d7e-4d65-8f65-dc1dba410ccc">"regional" constructed for profile 29.</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Part of a solution to an interpretation exercise (see docs and links in clean version for task). This shows a "regional" on the yellow horizon that indicates the underlying structure is contractional. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=958b5dd2-97e6-4a41-93be-3d431417c2be"><img alt="" class="img-responsive" src="/uploaded/image/200802/6fe5069a-ea11-4ffc-b6e4-2fdf5f6bcf28.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=958b5dd2-97e6-4a41-93be-3d431417c2be">DW Niger delta fold - profile N29</a></span>
# <span class="label label-scene">Scene</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Interpretations:</th>
# <td>4</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2008-02-11</td>
# </tr>
# </tbody></table>
# <p>Fore-thrust structure from the deep water Western Niger Delta. SEE DOCS &amp; LINKS FOR INTERPRETATION EXERCISE.
#
# </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=2adc03aa-62f7-436e-9e3c-1951214cfb7e"><img alt="" class="img-responsive" src="/uploaded/image/202102/f1c6b095-51a5-4fb7-b5b1-d6ef25e37bd8.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=2adc03aa-62f7-436e-9e3c-1951214cfb7e">Rotational faulted minibasins, offshore Morocco</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Listric normal faults with growth strata formed above a mobile substrate (salt) </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=2e8dcb70-6282-49fe-b6ed-b9a117637771"><img alt="" class="img-responsive" src="/uploaded/image/202102/3cefee84-7033-4ed4-848e-83d3fa259cd7.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=2e8dcb70-6282-49fe-b6ed-b9a117637771">Normal faults, offshore Tunisia</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Normal faults interpreted for parts of the image. Note vertical scale - implies significant vertical exaggeration. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=f533bd43-b82f-4d4f-98d4-c3a3be180045"><img alt="" class="img-responsive" src="/uploaded/image/202102/91bd7827-8b8a-4320-bbbf-02a9d8ab6731.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=f533bd43-b82f-4d4f-98d4-c3a3be180045">Moray Firth Fault Zone 2 - interpreted with high VE</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Various imaging issues associated with this example - including a weak sea-bottom multiple that obscures the shallow structure of the fault block. Further imaging issues arise here as more lithified strata are on the seabed (hence higher amplitude sea bottom reflector) which impedes energy penetration. Additional structural complexity (addition faults?) reduce image quality (migration...</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=0e66bd4e-809b-4ca7-8003-fdb2708e0d93"><img alt="" class="img-responsive" src="/uploaded/image/202102/fbf8e47a-66b6-44b8-8126-44bbeb149077.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=0e66bd4e-809b-4ca7-8003-fdb2708e0d93">Moray Fault Zone 2 - low VE</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>A normal fault zone - with some identified imaging issues. Note too the hangingwall synform - presumably caused by distributed normal shear (breached tip-line folding).</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=95282284-bce7-44f8-b75d-8d5ba443d97e"><img alt="" class="img-responsive" src="/uploaded/image/202102/e3ef9772-7452-4b51-a200-ed61c802fb92.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=95282284-bce7-44f8-b75d-8d5ba443d97e">Faulting at the limit of seismic resolution, offshore NW Morocco.</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>See also annotated version. Faults in ?contourites  The faults are represented variably with depth as frequency and amplitude of reflectors vary. Do the complex patterns to R of section represent closely spaced faults (i.e. real geological deformation) or seismic noise (or both!). The bright, inclined reflectors - are these remobiilsed sand - (sandstone injections) along fault planes,...</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=e17d49c3-8ac1-4580-b0f4-657942d678bf"><img alt="" class="img-responsive" src="/uploaded/image/202102/0fb92504-62e5-458e-b943-8fc0d224830a.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=e17d49c3-8ac1-4580-b0f4-657942d678bf">Offshore Apulian fault scarp - less VE</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>An approximated representation of the offshore scarp on the Apulian fault, with rather little vertical exaggeration. See alternative interpretation for imaging issues. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=b8305487-9a32-476e-b1cd-3c4d004276d5"><img alt="" class="img-responsive" src="/uploaded/image/202102/3d9da7c8-0633-4349-909a-8a8aa39847d6.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=b8305487-9a32-476e-b1cd-3c4d004276d5">Offshore Apulian fault scarp</a></span>
# <span class="label label-scene">Scene</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Interpretations:</th>
# <td>2</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Seabed escarpment along the offshore Apulian fault. Very high vertical exaggeration... see interpretations... </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=3218bafa-1b27-42a8-bff9-13b6bd2a9589"><img alt="" class="img-responsive" src="/uploaded/image/201003/bb3710d6-e35d-445f-907f-e45fa065c996.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=3218bafa-1b27-42a8-bff9-13b6bd2a9589">Visualising seismic data in 3D - Gulf of Mexico 1, West Cameron 1</a></span>
# <span class="label label-regional">Regional Project</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Alan Roberts</td>
# </tr>
# <tr>
# <th>Scenes:</th>
# <td>0</td>
# </tr>
# <tr>
# <th>Interpretations:</th>
# <td>0</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2010-03-05</td>
# </tr>
# </tbody></table>
# <p>This image shows two seismic probes, within the same 3D data volume, plus an interpreted horizon surface. The probe on the left is a variable amplitude display and normal fault traces can be seen on both vertical surfaces and on the horizontal time-slice. The probe on the right is a coherency display and the fault traces are particularly clear on the horizontal upper surface. The inte...</p>
# </section>
# </div>
# </div>
# </div>
# <footer>
# <div>
# 			Copyright © 2014 <b>Virtual Seismic Atlas</b>
# 			| <a href="/terms">Terms of Use</a>
# 			| <a href="/help">Contact</a>
# </div>
# <script>
# 		  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 		  ga('create', 'UA-52988538-1', 'auto');
# 		  ga('send', 'pageview');
#
# 		</script>
# </footer>
# <script src="/resources/js/jquery-1.11.0.min.js"></script>
# <script src="/resources/js/js-webshim/minified/polyfiller.js"></script>
# <script src="/resources/js/bootstrap.min.js"></script>
# <script src="/resources/js/main.js"></script>
# </body></html>

# %%
faults_content_div = doc_faults_1.find('div', class_='content')
faults_content_div
# Out:
# <div class="col-xs-9 content">
# <div class="facet-label">
# <a class="btn btn-xxxs btn-danger" href="https://seismicatlas.org/search?pn=0&amp;f=&amp;s="><span class="glyphicon glyphicon-remove"></span></a>
# <span>Deformation Structures:</span>
# <a class="text" href="https://seismicatlas.org/search?pn=0&amp;f=&amp;s=" title="Click to Remove">Faults</a>
# </div>
# <small>Use the options on the left to narrow your search further, or to widen your search, you can remove previous selections from the list above.</small>
# <br/>
# <br/><br/>
# <form action="" class="pagination-heading" method="get" role="form">
# <input name="f" type="hidden" value="1003"/>
# <input name="pn" type="hidden" value="0"/>
# <div class="row">
# <div class="col-md-3 col-sm-6 nowrap">
# <div class="form-group">
# <p class="form-control-static"><b>Results: 1-25 of 392</b></p>
# </div>
# </div>
# <div class="col-md-3 col-sm-6 pull-right">
# <div class="pull-right">
# <div class="btn-group">
# <button class="btn btn-default btn-sm dropdown-toggle" data-toggle="dropdown" type="button">
#                         Display settings
#                         <span class="caret"></span>
# </button>
# <div class="dropdown-menu dropdown-menu-right" role="menu" style="">
# <br/>
# <div class="form-horizontal" style="width: 300px; padding: 20px;">
# <div class="form-group">
# <label class="col-xs-6" for="input_sort_by">Sort by:</label>
# <div class="col-xs-6">
# <select class="form-control input-sm" id="input_sort_by" name="sb">
# <option value="relevance">Relevance</option>
# <option value="name">Display Name</option>
# <option selected="selected" value="date">Date Modified</option>
# </select>
# </div>
# </div>
# <div class="form-group">
# <label class="col-xs-6" for="input_sort_order">Sort order:</label>
# <div class="col-xs-6">
# <select class="form-control input-sm" id="input_sort_order" name="so">
# <option value="asc">Ascending</option>
# <option selected="selected" value="desc">Descending</option>
# </select>
# </div>
# </div>
# <div class="form-group">
# <label class="col-xs-6" for="input_items_per_page">Items per page:</label>
# <div class="col-xs-6">
# <select class="form-control input-sm" id="input_items_per_page" name="ps">
# <option value="10">10</option>
# <option selected="selected" value="25">25</option>
# <option value="50">50</option>
# </select>
# </div>
# </div>
# <div class="form-group">
# <div class="col-xs-offset-2 col-xs-8 text-center">
# <button class="btn btn-default btn-xs" type="submit"><span class="glyphicon glyphicon-ok"></span> Apply</button>
# <button class="btn btn-default btn-xs" type="reset"><span class="glyphicon glyphicon-remove"></span> Cancel</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-6 col-sm-12 text-right nowrap">
# <ul class="pager">
# <li><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=0"><span class="glyphicon icon-first"></span></a></li>
# <li class="active" href="#"><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=0">1</a></li>
# <li href="#"><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=1">2</a></li>
# <li href="#"><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=2">3</a></li>
# <li href="#"><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=3">4</a></li>
# <li href="#"><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=4">5</a></li>
# <li><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=1">Next <span class="glyphicon icon-next"></span></a></li>
# <li><a href="https://seismicatlas.org/search?f=1003&amp;s&amp;pn=15"><span class="glyphicon icon-last"></span></a></li>
# </ul>
# </div>
# </div>
# </form>
# <section>
# <figure class="thumbnail"><a href="/entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad"><img alt="" class="img-responsive" src="/uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad">Crustal Structure, West Orkney Basin, imaged by MOIST</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-03-12</td>
# </tr>
# </tbody></table>
# <p>An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17). </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139"><img alt="" class="img-responsive" src="/uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139">Deep structure - Outer Isles Fault - from WINCH 1 profile</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-03-12</td>
# </tr>
# </tbody></table>
# <p>An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a"><img alt="" class="img-responsive" src="/uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a">Deep Structure - West Orkney Basin, imaged on ultradeep seismic</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-03-12</td>
# </tr>
# </tbody></table>
# <p>An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W"). </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=d89526c0-b276-4815-98fb-e2f99515195f"><img alt="" class="img-responsive" src="/uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=d89526c0-b276-4815-98fb-e2f99515195f">Deep structure Western Orkney Basin - from GRID17 (SLAVE)</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-03-12</td>
# </tr>
# </tbody></table>
# <p>Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=7998e3da-2a89-4835-8809-e659078811aa"><img alt="" class="img-responsive" src="/uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=7998e3da-2a89-4835-8809-e659078811aa">Inversion, North Sea</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-19</td>
# </tr>
# </tbody></table>
# <p>An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0"><img alt="" class="img-responsive" src="/uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0">Interpreting a deepwater thrust system, offshore Namibia</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-18</td>
# </tr>
# </tbody></table>
# <p>An interpretation of a deepwater thrust belt. See associated scene if you'd like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=c56c95c3-d872-4b51-88c1-0f05d39effeb"><img alt="" class="img-responsive" src="/uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=c56c95c3-d872-4b51-88c1-0f05d39effeb">Faults and graben (less VE version), offshore Tunisia</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-06</td>
# </tr>
# </tbody></table>
# <p>A rather better representation of faults and graben structure, with less vertical exaggeration. See the alternate interpretation for comparison. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=ba4bfcdc-5596-45a2-a320-88622c9f49b3"><img alt="" class="img-responsive" src="/uploaded/image/201309/21916a9a-2153-4ed2-9d89-5d005f5bdea5.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=ba4bfcdc-5596-45a2-a320-88622c9f49b3">Seismic stratigraphy exercise</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Julien Moreau</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2013-09-12</td>
# </tr>
# </tbody></table>
# <p>Correction of a seismic interpretation exercise I gave.
# The interpretation is uniquely based on reflection termination picking which indicate bounding surfaces. No model is involved.
# Colours between two successive bounding surfaces have no genetic meaning they only give a sort of chronology through the repetition of a colour cycle (blue, pink, green,yellow) .
# The objective of the exer...</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=6157758c-059b-4efd-995b-1f0058a2473f"><img alt="" class="img-responsive" src="/uploaded/image/202102/aec6418e-052c-4295-b65c-b8c7e610ff7a.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=6157758c-059b-4efd-995b-1f0058a2473f">Closely spaced faults - and imaging issues, offshore NW Morocco</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>This and associated interpretation (annotated) shows array of "synthetic" normal faults offsetting high-frequrency reflectors (probable contourites). </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=8f3d5439-6dc2-4c68-9664-e6839b496277"><img alt="" class="img-responsive" src="/uploaded/image/200908/4be2aa3a-a452-4bc0-bc90-f4e6524370a9.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=8f3d5439-6dc2-4c68-9664-e6839b496277">A high resolution version of the thrust belt, Namibia</a></span>
# <span class="label label-scene">Scene</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Interpretations:</th>
# <td>0</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2009-08-17</td>
# </tr>
# </tbody></table>
# <p>High quality seismic reflection data reveal thrust and fold structural geometry offshore Namibia. The lack of image distortion and amplitude variations associated with structures indicates a generally simple seismic velocity structure that is a function of depth rather than stratigraphy. Note the preservation of amplitude up to the thrust cut-offs, with almost no loss in data quality....</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=922c7210-5e4a-4945-8bea-8fa95574364b"><img alt="" class="img-responsive" src="/uploaded/image/202001/462e8987-c4d2-493c-b77e-c60c0be9dd62.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=922c7210-5e4a-4945-8bea-8fa95574364b">The Moray Firth exercise interp annotated </a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2020-01-20</td>
# </tr>
# </tbody></table>
# <p>This is the annotated version - with labelled megasequences and selected structures. Note that the boxed area (R side) is considered to have a high uncertainty - stemming from problems correlating stratal reflectors which are rather discontinuous here. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=b047b8a3-26ff-4198-ba0c-ea8fb418c524"><img alt="" class="img-responsive" src="/uploaded/image/202102/42954b88-dd40-49db-9621-f324257078f6.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=b047b8a3-26ff-4198-ba0c-ea8fb418c524">Interpretation solution to exercise - profile 29. </a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Interpretation (solution) to interpretation exercise (see clean image). The DOCS AND LINKS HERE has a step-wise pdf solution. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=055c90aa-f84c-449a-8f25-ca6581235e7d"><img alt="" class="img-responsive" src="/uploaded/image/202102/704bc1b9-0922-4556-9e8f-92ce870076a3.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=055c90aa-f84c-449a-8f25-ca6581235e7d">Faults and graben structure, offshore Tunisia</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-06</td>
# </tr>
# </tbody></table>
# <p>This interpretation shows faults continuing to depth. The fault geometries on the right are obscured by migration and fault-shadowing artifacts. Note the scale - interpretation (less VE) version gives a more "realistic representation of basin structure. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=45825358-bfaa-41b9-aa4d-20d413d7ffcd"><img alt="" class="img-responsive" src="/uploaded/image/202102/10317df6-a715-4a48-b4e6-bc3e9e67d060.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=45825358-bfaa-41b9-aa4d-20d413d7ffcd">Imaging issues on the Apulian fault</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Apulian fault scarp - the seabed expression of a normal fault. The interpretation shows the image distortions that result - with dimming a migration problems in both the hangingwall and footwall. The image has very high (&gt; x5) vertical exaggeration of the seabed. See the alternate interpretation for a more realistic display. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=f6c7b5b1-f344-4b95-b1a7-8032e50e8dba"><img alt="" class="img-responsive" src="/uploaded/image/202102/e9a2f32e-be00-4448-bd67-d94ecae41727.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=f6c7b5b1-f344-4b95-b1a7-8032e50e8dba">Faults in shallow section of the Inner Moray Firth</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>An interpretation of faults and stratal reflectors. The clean version is set up as an interpretation exercise.</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=0ccd2827-2d7e-4d65-8f65-dc1dba410ccc"><img alt="" class="img-responsive" src="/uploaded/image/202102/a2649f5d-bdb4-4d8a-94ca-d0b79e9d9421.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=0ccd2827-2d7e-4d65-8f65-dc1dba410ccc">"regional" constructed for profile 29.</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Part of a solution to an interpretation exercise (see docs and links in clean version for task). This shows a "regional" on the yellow horizon that indicates the underlying structure is contractional. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=958b5dd2-97e6-4a41-93be-3d431417c2be"><img alt="" class="img-responsive" src="/uploaded/image/200802/6fe5069a-ea11-4ffc-b6e4-2fdf5f6bcf28.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=958b5dd2-97e6-4a41-93be-3d431417c2be">DW Niger delta fold - profile N29</a></span>
# <span class="label label-scene">Scene</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Interpretations:</th>
# <td>4</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2008-02-11</td>
# </tr>
# </tbody></table>
# <p>Fore-thrust structure from the deep water Western Niger Delta. SEE DOCS &amp; LINKS FOR INTERPRETATION EXERCISE.
#
# </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=2adc03aa-62f7-436e-9e3c-1951214cfb7e"><img alt="" class="img-responsive" src="/uploaded/image/202102/f1c6b095-51a5-4fb7-b5b1-d6ef25e37bd8.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=2adc03aa-62f7-436e-9e3c-1951214cfb7e">Rotational faulted minibasins, offshore Morocco</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Listric normal faults with growth strata formed above a mobile substrate (salt) </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=2e8dcb70-6282-49fe-b6ed-b9a117637771"><img alt="" class="img-responsive" src="/uploaded/image/202102/3cefee84-7033-4ed4-848e-83d3fa259cd7.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=2e8dcb70-6282-49fe-b6ed-b9a117637771">Normal faults, offshore Tunisia</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Normal faults interpreted for parts of the image. Note vertical scale - implies significant vertical exaggeration. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=f533bd43-b82f-4d4f-98d4-c3a3be180045"><img alt="" class="img-responsive" src="/uploaded/image/202102/91bd7827-8b8a-4320-bbbf-02a9d8ab6731.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=f533bd43-b82f-4d4f-98d4-c3a3be180045">Moray Firth Fault Zone 2 - interpreted with high VE</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Various imaging issues associated with this example - including a weak sea-bottom multiple that obscures the shallow structure of the fault block. Further imaging issues arise here as more lithified strata are on the seabed (hence higher amplitude sea bottom reflector) which impedes energy penetration. Additional structural complexity (addition faults?) reduce image quality (migration...</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=0e66bd4e-809b-4ca7-8003-fdb2708e0d93"><img alt="" class="img-responsive" src="/uploaded/image/202102/fbf8e47a-66b6-44b8-8126-44bbeb149077.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=0e66bd4e-809b-4ca7-8003-fdb2708e0d93">Moray Fault Zone 2 - low VE</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>A normal fault zone - with some identified imaging issues. Note too the hangingwall synform - presumably caused by distributed normal shear (breached tip-line folding).</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=95282284-bce7-44f8-b75d-8d5ba443d97e"><img alt="" class="img-responsive" src="/uploaded/image/202102/e3ef9772-7452-4b51-a200-ed61c802fb92.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=95282284-bce7-44f8-b75d-8d5ba443d97e">Faulting at the limit of seismic resolution, offshore NW Morocco.</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>See also annotated version. Faults in ?contourites  The faults are represented variably with depth as frequency and amplitude of reflectors vary. Do the complex patterns to R of section represent closely spaced faults (i.e. real geological deformation) or seismic noise (or both!). The bright, inclined reflectors - are these remobiilsed sand - (sandstone injections) along fault planes,...</p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=e17d49c3-8ac1-4580-b0f4-657942d678bf"><img alt="" class="img-responsive" src="/uploaded/image/202102/0fb92504-62e5-458e-b943-8fc0d224830a.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=e17d49c3-8ac1-4580-b0f4-657942d678bf">Offshore Apulian fault scarp - less VE</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>An approximated representation of the offshore scarp on the Apulian fault, with rather little vertical exaggeration. See alternative interpretation for imaging issues. </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=b8305487-9a32-476e-b1cd-3c4d004276d5"><img alt="" class="img-responsive" src="/uploaded/image/202102/3d9da7c8-0633-4349-909a-8a8aa39847d6.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=b8305487-9a32-476e-b1cd-3c4d004276d5">Offshore Apulian fault scarp</a></span>
# <span class="label label-scene">Scene</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Interpretations:</th>
# <td>2</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2021-02-01</td>
# </tr>
# </tbody></table>
# <p>Seabed escarpment along the offshore Apulian fault. Very high vertical exaggeration... see interpretations... </p>
# </section>
# <section>
# <figure class="thumbnail"><a href="/entity?id=3218bafa-1b27-42a8-bff9-13b6bd2a9589"><img alt="" class="img-responsive" src="/uploaded/image/201003/bb3710d6-e35d-445f-907f-e45fa065c996.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=3218bafa-1b27-42a8-bff9-13b6bd2a9589">Visualising seismic data in 3D - Gulf of Mexico 1, West Cameron 1</a></span>
# <span class="label label-regional">Regional Project</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Alan Roberts</td>
# </tr>
# <tr>
# <th>Scenes:</th>
# <td>0</td>
# </tr>
# <tr>
# <th>Interpretations:</th>
# <td>0</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2010-03-05</td>
# </tr>
# </tbody></table>
# <p>This image shows two seismic probes, within the same 3D data volume, plus an interpreted horizon surface. The probe on the left is a variable amplitude display and normal fault traces can be seen on both vertical surfaces and on the horizontal time-slice. The probe on the right is a coherency display and the fault traces are particularly clear on the horizontal upper surface. The inte...</p>
# </section>
# </div>

# %%
faults_sections = faults_content_div.find_all('section')
faults_sections
# Out:
# [<section>
#  <figure class="thumbnail"><a href="/entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad"><img alt="" class="img-responsive" src="/uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad">Crustal Structure, West Orkney Basin, imaged by MOIST</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-03-12</td>
#  </tr>
#  </tbody></table>
#  <p>An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17). </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139"><img alt="" class="img-responsive" src="/uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139">Deep structure - Outer Isles Fault - from WINCH 1 profile</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-03-12</td>
#  </tr>
#  </tbody></table>
#  <p>An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure. </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a"><img alt="" class="img-responsive" src="/uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a">Deep Structure - West Orkney Basin, imaged on ultradeep seismic</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-03-12</td>
#  </tr>
#  </tbody></table>
#  <p>An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W"). </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=d89526c0-b276-4815-98fb-e2f99515195f"><img alt="" class="img-responsive" src="/uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=d89526c0-b276-4815-98fb-e2f99515195f">Deep structure Western Orkney Basin - from GRID17 (SLAVE)</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-03-12</td>
#  </tr>
#  </tbody></table>
#  <p>Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")</p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=7998e3da-2a89-4835-8809-e659078811aa"><img alt="" class="img-responsive" src="/uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=7998e3da-2a89-4835-8809-e659078811aa">Inversion, North Sea</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-19</td>
#  </tr>
#  </tbody></table>
#  <p>An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces. </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0"><img alt="" class="img-responsive" src="/uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0">Interpreting a deepwater thrust system, offshore Namibia</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-18</td>
#  </tr>
#  </tbody></table>
#  <p>An interpretation of a deepwater thrust belt. See associated scene if you'd like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow. </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=c56c95c3-d872-4b51-88c1-0f05d39effeb"><img alt="" class="img-responsive" src="/uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=c56c95c3-d872-4b51-88c1-0f05d39effeb">Faults and graben (less VE version), offshore Tunisia</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-06</td>
#  </tr>
#  </tbody></table>
#  <p>A rather better representation of faults and graben structure, with less vertical exaggeration. See the alternate interpretation for comparison. </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=ba4bfcdc-5596-45a2-a320-88622c9f49b3"><img alt="" class="img-responsive" src="/uploaded/image/201309/21916a9a-2153-4ed2-9d89-5d005f5bdea5.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=ba4bfcdc-5596-45a2-a320-88622c9f49b3">Seismic stratigraphy exercise</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Julien Moreau</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2013-09-12</td>
#  </tr>
#  </tbody></table>
#  <p>Correction of a seismic interpretation exercise I gave.
#  The interpretation is uniquely based on reflection termination picking which indicate bounding surfaces. No model is involved.
#  Colours between two successive bounding surfaces have no genetic meaning they only give a sort of chronology through the repetition of a colour cycle (blue, pink, green,yellow) .
#  The objective of the exer...</p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=6157758c-059b-4efd-995b-1f0058a2473f"><img alt="" class="img-responsive" src="/uploaded/image/202102/aec6418e-052c-4295-b65c-b8c7e610ff7a.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=6157758c-059b-4efd-995b-1f0058a2473f">Closely spaced faults - and imaging issues, offshore NW Morocco</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-01</td>
#  </tr>
#  </tbody></table>
#  <p>This and associated interpretation (annotated) shows array of "synthetic" normal faults offsetting high-frequrency reflectors (probable contourites). </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=8f3d5439-6dc2-4c68-9664-e6839b496277"><img alt="" class="img-responsive" src="/uploaded/image/200908/4be2aa3a-a452-4bc0-bc90-f4e6524370a9.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=8f3d5439-6dc2-4c68-9664-e6839b496277">A high resolution version of the thrust belt, Namibia</a></span>
#  <span class="label label-scene">Scene</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Interpretations:</th>
#  <td>0</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2009-08-17</td>
#  </tr>
#  </tbody></table>
#  <p>High quality seismic reflection data reveal thrust and fold structural geometry offshore Namibia. The lack of image distortion and amplitude variations associated with structures indicates a generally simple seismic velocity structure that is a function of depth rather than stratigraphy. Note the preservation of amplitude up to the thrust cut-offs, with almost no loss in data quality....</p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=922c7210-5e4a-4945-8bea-8fa95574364b"><img alt="" class="img-responsive" src="/uploaded/image/202001/462e8987-c4d2-493c-b77e-c60c0be9dd62.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=922c7210-5e4a-4945-8bea-8fa95574364b">The Moray Firth exercise interp annotated </a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2020-01-20</td>
#  </tr>
#  </tbody></table>
#  <p>This is the annotated version - with labelled megasequences and selected structures. Note that the boxed area (R side) is considered to have a high uncertainty - stemming from problems correlating stratal reflectors which are rather discontinuous here. </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=b047b8a3-26ff-4198-ba0c-ea8fb418c524"><img alt="" class="img-responsive" src="/uploaded/image/202102/42954b88-dd40-49db-9621-f324257078f6.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=b047b8a3-26ff-4198-ba0c-ea8fb418c524">Interpretation solution to exercise - profile 29. </a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-01</td>
#  </tr>
#  </tbody></table>
#  <p>Interpretation (solution) to interpretation exercise (see clean image). The DOCS AND LINKS HERE has a step-wise pdf solution. </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=055c90aa-f84c-449a-8f25-ca6581235e7d"><img alt="" class="img-responsive" src="/uploaded/image/202102/704bc1b9-0922-4556-9e8f-92ce870076a3.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=055c90aa-f84c-449a-8f25-ca6581235e7d">Faults and graben structure, offshore Tunisia</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-06</td>
#  </tr>
#  </tbody></table>
#  <p>This interpretation shows faults continuing to depth. The fault geometries on the right are obscured by migration and fault-shadowing artifacts. Note the scale - interpretation (less VE) version gives a more "realistic representation of basin structure. </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=45825358-bfaa-41b9-aa4d-20d413d7ffcd"><img alt="" class="img-responsive" src="/uploaded/image/202102/10317df6-a715-4a48-b4e6-bc3e9e67d060.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=45825358-bfaa-41b9-aa4d-20d413d7ffcd">Imaging issues on the Apulian fault</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-01</td>
#  </tr>
#  </tbody></table>
#  <p>Apulian fault scarp - the seabed expression of a normal fault. The interpretation shows the image distortions that result - with dimming a migration problems in both the hangingwall and footwall. The image has very high (&gt; x5) vertical exaggeration of the seabed. See the alternate interpretation for a more realistic display. </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=f6c7b5b1-f344-4b95-b1a7-8032e50e8dba"><img alt="" class="img-responsive" src="/uploaded/image/202102/e9a2f32e-be00-4448-bd67-d94ecae41727.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=f6c7b5b1-f344-4b95-b1a7-8032e50e8dba">Faults in shallow section of the Inner Moray Firth</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-01</td>
#  </tr>
#  </tbody></table>
#  <p>An interpretation of faults and stratal reflectors. The clean version is set up as an interpretation exercise.</p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=0ccd2827-2d7e-4d65-8f65-dc1dba410ccc"><img alt="" class="img-responsive" src="/uploaded/image/202102/a2649f5d-bdb4-4d8a-94ca-d0b79e9d9421.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=0ccd2827-2d7e-4d65-8f65-dc1dba410ccc">"regional" constructed for profile 29.</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-01</td>
#  </tr>
#  </tbody></table>
#  <p>Part of a solution to an interpretation exercise (see docs and links in clean version for task). This shows a "regional" on the yellow horizon that indicates the underlying structure is contractional. </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=958b5dd2-97e6-4a41-93be-3d431417c2be"><img alt="" class="img-responsive" src="/uploaded/image/200802/6fe5069a-ea11-4ffc-b6e4-2fdf5f6bcf28.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=958b5dd2-97e6-4a41-93be-3d431417c2be">DW Niger delta fold - profile N29</a></span>
#  <span class="label label-scene">Scene</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Interpretations:</th>
#  <td>4</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-11</td>
#  </tr>
#  </tbody></table>
#  <p>Fore-thrust structure from the deep water Western Niger Delta. SEE DOCS &amp; LINKS FOR INTERPRETATION EXERCISE.
#
#  </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=2adc03aa-62f7-436e-9e3c-1951214cfb7e"><img alt="" class="img-responsive" src="/uploaded/image/202102/f1c6b095-51a5-4fb7-b5b1-d6ef25e37bd8.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=2adc03aa-62f7-436e-9e3c-1951214cfb7e">Rotational faulted minibasins, offshore Morocco</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-01</td>
#  </tr>
#  </tbody></table>
#  <p>Listric normal faults with growth strata formed above a mobile substrate (salt) </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=2e8dcb70-6282-49fe-b6ed-b9a117637771"><img alt="" class="img-responsive" src="/uploaded/image/202102/3cefee84-7033-4ed4-848e-83d3fa259cd7.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=2e8dcb70-6282-49fe-b6ed-b9a117637771">Normal faults, offshore Tunisia</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-01</td>
#  </tr>
#  </tbody></table>
#  <p>Normal faults interpreted for parts of the image. Note vertical scale - implies significant vertical exaggeration. </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=f533bd43-b82f-4d4f-98d4-c3a3be180045"><img alt="" class="img-responsive" src="/uploaded/image/202102/91bd7827-8b8a-4320-bbbf-02a9d8ab6731.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=f533bd43-b82f-4d4f-98d4-c3a3be180045">Moray Firth Fault Zone 2 - interpreted with high VE</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-01</td>
#  </tr>
#  </tbody></table>
#  <p>Various imaging issues associated with this example - including a weak sea-bottom multiple that obscures the shallow structure of the fault block. Further imaging issues arise here as more lithified strata are on the seabed (hence higher amplitude sea bottom reflector) which impedes energy penetration. Additional structural complexity (addition faults?) reduce image quality (migration...</p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=0e66bd4e-809b-4ca7-8003-fdb2708e0d93"><img alt="" class="img-responsive" src="/uploaded/image/202102/fbf8e47a-66b6-44b8-8126-44bbeb149077.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=0e66bd4e-809b-4ca7-8003-fdb2708e0d93">Moray Fault Zone 2 - low VE</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-01</td>
#  </tr>
#  </tbody></table>
#  <p>A normal fault zone - with some identified imaging issues. Note too the hangingwall synform - presumably caused by distributed normal shear (breached tip-line folding).</p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=95282284-bce7-44f8-b75d-8d5ba443d97e"><img alt="" class="img-responsive" src="/uploaded/image/202102/e3ef9772-7452-4b51-a200-ed61c802fb92.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=95282284-bce7-44f8-b75d-8d5ba443d97e">Faulting at the limit of seismic resolution, offshore NW Morocco.</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-01</td>
#  </tr>
#  </tbody></table>
#  <p>See also annotated version. Faults in ?contourites  The faults are represented variably with depth as frequency and amplitude of reflectors vary. Do the complex patterns to R of section represent closely spaced faults (i.e. real geological deformation) or seismic noise (or both!). The bright, inclined reflectors - are these remobiilsed sand - (sandstone injections) along fault planes,...</p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=e17d49c3-8ac1-4580-b0f4-657942d678bf"><img alt="" class="img-responsive" src="/uploaded/image/202102/0fb92504-62e5-458e-b943-8fc0d224830a.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=e17d49c3-8ac1-4580-b0f4-657942d678bf">Offshore Apulian fault scarp - less VE</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-01</td>
#  </tr>
#  </tbody></table>
#  <p>An approximated representation of the offshore scarp on the Apulian fault, with rather little vertical exaggeration. See alternative interpretation for imaging issues. </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=b8305487-9a32-476e-b1cd-3c4d004276d5"><img alt="" class="img-responsive" src="/uploaded/image/202102/3d9da7c8-0633-4349-909a-8a8aa39847d6.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=b8305487-9a32-476e-b1cd-3c4d004276d5">Offshore Apulian fault scarp</a></span>
#  <span class="label label-scene">Scene</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Interpretations:</th>
#  <td>2</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2021-02-01</td>
#  </tr>
#  </tbody></table>
#  <p>Seabed escarpment along the offshore Apulian fault. Very high vertical exaggeration... see interpretations... </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=3218bafa-1b27-42a8-bff9-13b6bd2a9589"><img alt="" class="img-responsive" src="/uploaded/image/201003/bb3710d6-e35d-445f-907f-e45fa065c996.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=3218bafa-1b27-42a8-bff9-13b6bd2a9589">Visualising seismic data in 3D - Gulf of Mexico 1, West Cameron 1</a></span>
#  <span class="label label-regional">Regional Project</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Alan Roberts</td>
#  </tr>
#  <tr>
#  <th>Scenes:</th>
#  <td>0</td>
#  </tr>
#  <tr>
#  <th>Interpretations:</th>
#  <td>0</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2010-03-05</td>
#  </tr>
#  </tbody></table>
#  <p>This image shows two seismic probes, within the same 3D data volume, plus an interpreted horizon surface. The probe on the left is a variable amplitude display and normal fault traces can be seen on both vertical surfaces and on the horizontal time-slice. The probe on the right is a coherency display and the fault traces are particularly clear on the horizontal upper surface. The inte...</p>
#  </section>]

# %%
faults_title_tags = faults_sections[0].find_all('a')[1].text
faults_title_tags
# Out:
# 'Crustal Structure, West Orkney Basin, imaged by MOIST'

# %%
faults_label_tags = faults_sections[0].find_all('span', {'class' : "label"})[0].text
faults_label_tags
# Out:
# 'Interpretation'

# %%
faults_authorname_tags = faults_sections[0].find_all('td')[0].text
faults_authorname_tags
# Out:
# 'Rob Butler'

# %%
faults_date_tags = faults_sections[0].find_all('td')[-1].text
faults_date_tags
# Out:
# '2021-03-12'

# %%
faults_base_url = 'https://seismicatlas.org//'

faults_img_tags = faults_sections[0]("img", {'class' : "img-responsive"})[0]['src']
faults_img_url = faults_base_url + faults_img_tags
faults_img_url
# Out:
# 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg'

# %%
faults_desc_tags = faults_sections[0].find_all('p')[0].text
faults_desc_tags
# Out:
# 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17). '

# %%
faults_base_url = 'https://seismicatlas.org//'

faults_info_tags = faults_sections[0].find('a')['href']
faults_info_url = faults_base_url + faults_info_tags
faults_info_url
# Out:
# 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'

# %%
faults_base_url = 'https://seismicatlas.org//'

def parse_faults_section(section):
    
    faults_title = section.find_all('a')[1].text
    faults_data = section.find_all('span', {'class' : "label"})[0].text
    faults_authorname = section.find_all('td')[0].text
    faults_date = section.find_all('td')[-1].text
    faults_img_url = faults_base_url + section("img", {'class' : "img-responsive"})[0]['src']
    faults_description = section.find_all('p')[0].text.strip()
    faults_info_url = faults_base_url + section.find('a')['href']
    
    return {'Title': faults_title,
            'Data Type': faults_data,
            'Author': faults_authorname, 
            'Date': faults_date,
            'Image url': faults_img_url,
            'Description': faults_description, 
            'Info url': faults_info_url}

# %%
parse_faults_section(faults_sections[12])
# Out:
# {'Title': 'Faults and graben structure, offshore Tunisia',
#  'Data Type': 'Interpretation',
#  'Author': 'Rob Butler',
#  'Date': '2021-02-06',
#  'Image url': 'https://seismicatlas.org///uploaded/image/202102/704bc1b9-0922-4556-9e8f-92ce870076a3.jpg',
#  'Description': 'This interpretation shows faults continuing to depth. The fault geometries on the right are obscured by migration and fault-shadowing artifacts. Note the scale - interpretation (less VE) version gives a more "realistic representation of basin structure.',
#  'Info url': 'https://seismicatlas.org///entity?id=055c90aa-f84c-449a-8f25-ca6581235e7d'}

# %%
faults_sections_data = [parse_faults_section(section) for section in faults_sections]

# %%
faults_sections_data
# Out:
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-03-12',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg',
#   'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).',
#   'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'},
#  {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-03-12',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg',
#   'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.",
#   'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'},
#  {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-03-12',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg',
#   'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").',
#   'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'},
#  {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-03-12',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg',
#   'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")',
#   'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'},
#  {'Title': 'Inversion, North Sea',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-19',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg',
#   'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.',
#   'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'},
#  {'Title': 'Interpreting a deepwater thrust system, offshore Namibia',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-18',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg',
#   'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.',
#   'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'},
#  {'Title': 'Faults and graben (less VE version), offshore Tunisia',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-06',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg',
#   'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See the alternate interpretation for comparison.',
#   'Info url': 'https://seismicatlas.org///entity?id=c56c95c3-d872-4b51-88c1-0f05d39effeb'},
#  {'Title': 'Seismic stratigraphy exercise',
#   'Data Type': 'Interpretation',
#   'Author': 'Julien Moreau',
#   'Date': '2013-09-12',
#   'Image url': 'https://seismicatlas.org///uploaded/image/201309/21916a9a-2153-4ed2-9d89-5d005f5bdea5.jpg',
#   'Description': 'Correction of a seismic interpretation exercise I gave.\nThe interpretation is uniquely based on reflection termination picking which indicate bounding surfaces. No model is involved.\nColours between two successive bounding surfaces have no genetic meaning they only give a sort of chronology through the repetition of a colour cycle (blue, pink, green,yellow) .\nThe objective of the exer...',
#   'Info url': 'https://seismicatlas.org///entity?id=ba4bfcdc-5596-45a2-a320-88622c9f49b3'},
#  {'Title': 'Closely spaced faults - and imaging issues, offshore NW Morocco',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-01',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/aec6418e-052c-4295-b65c-b8c7e610ff7a.jpg',
#   'Description': 'This and associated interpretation (annotated) shows array of "synthetic" normal faults offsetting high-frequrency reflectors (probable contourites).',
#   'Info url': 'https://seismicatlas.org///entity?id=6157758c-059b-4efd-995b-1f0058a2473f'},
#  {'Title': 'A high resolution version of the thrust belt, Namibia',
#   'Data Type': 'Scene',
#   'Author': 'Rob Butler',
#   'Date': '2009-08-17',
#   'Image url': 'https://seismicatlas.org///uploaded/image/200908/4be2aa3a-a452-4bc0-bc90-f4e6524370a9.jpg',
#   'Description': 'High quality seismic reflection data reveal thrust and fold structural geometry offshore Namibia. The lack of image distortion and amplitude variations associated with structures indicates a generally simple seismic velocity structure that is a function of depth rather than stratigraphy. Note the preservation of amplitude up to the thrust cut-offs, with almost no loss in data quality....',
#   'Info url': 'https://seismicatlas.org///entity?id=8f3d5439-6dc2-4c68-9664-e6839b496277'},
#  {'Title': 'The Moray Firth exercise interp annotated ',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2020-01-20',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202001/462e8987-c4d2-493c-b77e-c60c0be9dd62.jpg',
#   'Description': 'This is the annotated version - with labelled megasequences and selected structures. Note that the boxed area (R side) is considered to have a high uncertainty - stemming from problems correlating stratal reflectors which are rather discontinuous here.',
#   'Info url': 'https://seismicatlas.org///entity?id=922c7210-5e4a-4945-8bea-8fa95574364b'},
#  {'Title': 'Interpretation solution to exercise - profile 29. ',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-01',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/42954b88-dd40-49db-9621-f324257078f6.jpg',
#   'Description': 'Interpretation (solution) to interpretation exercise (see clean image). The DOCS AND LINKS HERE has a step-wise pdf solution.',
#   'Info url': 'https://seismicatlas.org///entity?id=b047b8a3-26ff-4198-ba0c-ea8fb418c524'},
#  {'Title': 'Faults and graben structure, offshore Tunisia',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-06',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/704bc1b9-0922-4556-9e8f-92ce870076a3.jpg',
#   'Description': 'This interpretation shows faults continuing to depth. The fault geometries on the right are obscured by migration and fault-shadowing artifacts. Note the scale - interpretation (less VE) version gives a more "realistic representation of basin structure.',
#   'Info url': 'https://seismicatlas.org///entity?id=055c90aa-f84c-449a-8f25-ca6581235e7d'},
#  {'Title': 'Imaging issues on the Apulian fault',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-01',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/10317df6-a715-4a48-b4e6-bc3e9e67d060.jpg',
#   'Description': 'Apulian fault scarp - the seabed expression of a normal fault. The interpretation shows the image distortions that result - with dimming a migration problems in both the hangingwall and footwall. The image has very high (> x5) vertical exaggeration of the seabed. See the alternate interpretation for a more realistic display.',
#   'Info url': 'https://seismicatlas.org///entity?id=45825358-bfaa-41b9-aa4d-20d413d7ffcd'},
#  {'Title': 'Faults in shallow section of the Inner Moray Firth',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-01',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/e9a2f32e-be00-4448-bd67-d94ecae41727.jpg',
#   'Description': 'An interpretation of faults and stratal reflectors. The clean version is set up as an interpretation exercise.',
#   'Info url': 'https://seismicatlas.org///entity?id=f6c7b5b1-f344-4b95-b1a7-8032e50e8dba'},
#  {'Title': '"regional" constructed for profile 29.',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-01',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/a2649f5d-bdb4-4d8a-94ca-d0b79e9d9421.jpg',
#   'Description': 'Part of a solution to an interpretation exercise (see docs and links in clean version for task). This shows a "regional" on the yellow horizon that indicates the underlying structure is contractional.',
#   'Info url': 'https://seismicatlas.org///entity?id=0ccd2827-2d7e-4d65-8f65-dc1dba410ccc'},
#  {'Title': 'DW Niger delta fold - profile N29',
#   'Data Type': 'Scene',
#   'Author': 'Rob Butler',
#   'Date': '2008-02-11',
#   'Image url': 'https://seismicatlas.org///uploaded/image/200802/6fe5069a-ea11-4ffc-b6e4-2fdf5f6bcf28.jpg',
#   'Description': 'Fore-thrust structure from the deep water Western Niger Delta. SEE DOCS & LINKS FOR INTERPRETATION EXERCISE.',
#   'Info url': 'https://seismicatlas.org///entity?id=958b5dd2-97e6-4a41-93be-3d431417c2be'},
#  {'Title': 'Rotational faulted minibasins, offshore Morocco',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-01',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/f1c6b095-51a5-4fb7-b5b1-d6ef25e37bd8.jpg',
#   'Description': 'Listric normal faults with growth strata formed above a mobile substrate (salt)',
#   'Info url': 'https://seismicatlas.org///entity?id=2adc03aa-62f7-436e-9e3c-1951214cfb7e'},
#  {'Title': 'Normal faults, offshore Tunisia',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-01',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/3cefee84-7033-4ed4-848e-83d3fa259cd7.jpg',
#   'Description': 'Normal faults interpreted for parts of the image. Note vertical scale - implies significant vertical exaggeration.',
#   'Info url': 'https://seismicatlas.org///entity?id=2e8dcb70-6282-49fe-b6ed-b9a117637771'},
#  {'Title': 'Moray Firth Fault Zone 2 - interpreted with high VE',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-01',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/91bd7827-8b8a-4320-bbbf-02a9d8ab6731.jpg',
#   'Description': 'Various imaging issues associated with this example - including a weak sea-bottom multiple that obscures the shallow structure of the fault block. Further imaging issues arise here as more lithified strata are on the seabed (hence higher amplitude sea bottom reflector) which impedes energy penetration. Additional structural complexity (addition faults?) reduce image quality (migration...',
#   'Info url': 'https://seismicatlas.org///entity?id=f533bd43-b82f-4d4f-98d4-c3a3be180045'},
#  {'Title': 'Moray Fault Zone 2 - low VE',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-01',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/fbf8e47a-66b6-44b8-8126-44bbeb149077.jpg',
#   'Description': 'A normal fault zone - with some identified imaging issues. Note too the hangingwall synform - presumably caused by distributed normal shear (breached tip-line folding).',
#   'Info url': 'https://seismicatlas.org///entity?id=0e66bd4e-809b-4ca7-8003-fdb2708e0d93'},
#  {'Title': 'Faulting at the limit of seismic resolution, offshore NW Morocco.',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-01',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/e3ef9772-7452-4b51-a200-ed61c802fb92.jpg',
#   'Description': 'See also annotated version. Faults in ?contourites  The faults are represented variably with depth as frequency and amplitude of reflectors vary. Do the complex patterns to R of section represent closely spaced faults (i.e. real geological deformation) or seismic noise (or both!). The bright, inclined reflectors - are these remobiilsed sand - (sandstone injections) along fault planes,...',
#   'Info url': 'https://seismicatlas.org///entity?id=95282284-bce7-44f8-b75d-8d5ba443d97e'},
#  {'Title': 'Offshore Apulian fault scarp - less VE',
#   'Data Type': 'Interpretation',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-01',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/0fb92504-62e5-458e-b943-8fc0d224830a.jpg',
#   'Description': 'An approximated representation of the offshore scarp on the Apulian fault, with rather little vertical exaggeration. See alternative interpretation for imaging issues.',
#   'Info url': 'https://seismicatlas.org///entity?id=e17d49c3-8ac1-4580-b0f4-657942d678bf'},
#  {'Title': 'Offshore Apulian fault scarp',
#   'Data Type': 'Scene',
#   'Author': 'Rob Butler',
#   'Date': '2021-02-01',
#   'Image url': 'https://seismicatlas.org///uploaded/image/202102/3d9da7c8-0633-4349-909a-8a8aa39847d6.jpg',
#   'Description': 'Seabed escarpment along the offshore Apulian fault. Very high vertical exaggeration... see interpretations...',
#   'Info url': 'https://seismicatlas.org///entity?id=b8305487-9a32-476e-b1cd-3c4d004276d5'},
#  {'Title': 'Visualising seismic data in 3D - Gulf of Mexico 1, West Cameron 1',
#   'Data Type': 'Regional Project',
#   'Author': 'Alan Roberts',
#   'Date': '2010-03-05',
#   'Image url': 'https://seismicatlas.org///uploaded/image/201003/bb3710d6-e35d-445f-907f-e45fa065c996.jpg',
#   'Description': 'This image shows two seismic probes, within the same 3D data volume, plus an interpreted horizon surface. The probe on the left is a variable amplitude display and normal fault traces can be seen on both vertical surfaces and on the horizontal time-slice. The probe on the right is a coherency display and the fault traces are particularly clear on the horizontal upper surface. The inte...',
#   'Info url': 'https://seismicatlas.org///entity?id=3218bafa-1b27-42a8-bff9-13b6bd2a9589'}]

# %%
# faults_sections_data = []
# for section in faults_sections:
#     faults_sections_data.append(parse_faults_section(section))
    
#     print(faults_sections_data)

# %%
faults_sections_df = pd.DataFrame(faults_sections_data)

# %%
faults_sections_df
# Out:
#                                                 Title         Data Type  \
# 0   Crustal Structure, West Orkney Basin, imaged b...    Interpretation
# 1   Deep structure - Outer Isles Fault - from WINC...    Interpretation
# 2   Deep Structure - West Orkney Basin, imaged on ...    Interpretation
# 3   Deep structure Western Orkney Basin - from GRI...    Interpretation
# 4                                Inversion, North Sea    Interpretation
# 5   Interpreting a deepwater thrust system, offsho...    Interpretation
# 6   Faults and graben (less VE version), offshore ...    Interpretation
# 7                       Seismic stratigraphy exercise    Interpretation
# 8   Closely spaced faults - and imaging issues, of...    Interpretation
# 9   A high resolution version of the thrust belt, ...             Scene
# 10         The Moray Firth exercise interp annotated     Interpretation
# 11  Interpretation solution to exercise - profile ...    Interpretation
# 12      Faults and graben structure, offshore Tunisia    Interpretation
# 13                Imaging issues on the Apulian fault    Interpretation
# 14  Faults in shallow section of the Inner Moray F...    Interpretation
# 15             "regional" constructed for profile 29.    Interpretation
# 16                  DW Niger delta fold - profile N29             Scene
# 17    Rotational faulted minibasins, offshore Morocco    Interpretation
# 18                    Normal faults, offshore Tunisia    Interpretation
# 19  Moray Firth Fault Zone 2 - interpreted with hi...    Interpretation
# 20                        Moray Fault Zone 2 - low VE    Interpretation
# 21  Faulting at the limit of seismic resolution, o...    Interpretation
# 22             Offshore Apulian fault scarp - less VE    Interpretation
# 23                       Offshore Apulian fault scarp             Scene
# 24  Visualising seismic data in 3D - Gulf of Mexic...  Regional Project
#
#            Author        Date  \
# 0      Rob Butler  2021-03-12
# 1      Rob Butler  2021-03-12
# 2      Rob Butler  2021-03-12
# 3      Rob Butler  2021-03-12
# 4      Rob Butler  2021-02-19
# 5      Rob Butler  2021-02-18
# 6      Rob Butler  2021-02-06
# 7   Julien Moreau  2013-09-12
# 8      Rob Butler  2021-02-01
# 9      Rob Butler  2009-08-17
# 10     Rob Butler  2020-01-20
# 11     Rob Butler  2021-02-01
# 12     Rob Butler  2021-02-06
# 13     Rob Butler  2021-02-01
# 14     Rob Butler  2021-02-01
# 15     Rob Butler  2021-02-01
# 16     Rob Butler  2008-02-11
# 17     Rob Butler  2021-02-01
# 18     Rob Butler  2021-02-01
# 19     Rob Butler  2021-02-01
# 20     Rob Butler  2021-02-01
# 21     Rob Butler  2021-02-01
# 22     Rob Butler  2021-02-01
# 23     Rob Butler  2021-02-01
# 24   Alan Roberts  2010-03-05
#
#                                             Image url  \
# 0   https://seismicatlas.org///uploaded/image/2021...
# 1   https://seismicatlas.org///uploaded/image/2021...
# 2   https://seismicatlas.org///uploaded/image/2021...
# 3   https://seismicatlas.org///uploaded/image/2021...
# 4   https://seismicatlas.org///uploaded/image/2021...
# 5   https://seismicatlas.org///uploaded/image/2021...
# 6   https://seismicatlas.org///uploaded/image/2021...
# 7   https://seismicatlas.org///uploaded/image/2013...
# 8   https://seismicatlas.org///uploaded/image/2021...
# 9   https://seismicatlas.org///uploaded/image/2009...
# 10  https://seismicatlas.org///uploaded/image/2020...
# 11  https://seismicatlas.org///uploaded/image/2021...
# 12  https://seismicatlas.org///uploaded/image/2021...
# 13  https://seismicatlas.org///uploaded/image/2021...
# 14  https://seismicatlas.org///uploaded/image/2021...
# 15  https://seismicatlas.org///uploaded/image/2021...
# 16  https://seismicatlas.org///uploaded/image/2008...
# 17  https://seismicatlas.org///uploaded/image/2021...
# 18  https://seismicatlas.org///uploaded/image/2021...
# 19  https://seismicatlas.org///uploaded/image/2021...
# 20  https://seismicatlas.org///uploaded/image/2021...
# 21  https://seismicatlas.org///uploaded/image/2021...
# 22  https://seismicatlas.org///uploaded/image/2021...
# 23  https://seismicatlas.org///uploaded/image/2021...
# 24  https://seismicatlas.org///uploaded/image/2010...
#
#                                           Description  \
# 0   An interpretation of the first profile acquire...
# 1   An interpretation of BIRPS' WINCH-1 profile (f...
# 2   An interpretation of the BIRPS DRUM line (from...
# 3   Interpretation of the GRID 17 profile (aka Syn...
# 4   An interpretation of an inversion structure fr...
# 5   An interpretation of a deepwater thrust belt. ...
# 6   A rather better representation of faults and g...
# 7   Correction of a seismic interpretation exercis...
# 8   This and associated interpretation (annotated)...
# 9   High quality seismic reflection data reveal th...
# 10  This is the annotated version - with labelled ...
# 11  Interpretation (solution) to interpretation ex...
# 12  This interpretation shows faults continuing to...
# 13  Apulian fault scarp - the seabed expression of...
# 14  An interpretation of faults and stratal reflec...
# 15  Part of a solution to an interpretation exerci...
# 16  Fore-thrust structure from the deep water West...
# 17  Listric normal faults with growth strata forme...
# 18  Normal faults interpreted for parts of the ima...
# 19  Various imaging issues associated with this ex...
# 20  A normal fault zone - with some identified ima...
# 21  See also annotated version. Faults in ?contour...
# 22  An approximated representation of the offshore...
# 23  Seabed escarpment along the offshore Apulian f...
# 24  This image shows two seismic probes, within th...
#
#                                              Info url
# 0   https://seismicatlas.org///entity?id=cad7a17f-...
# 1   https://seismicatlas.org///entity?id=5daf55c7-...
# 2   https://seismicatlas.org///entity?id=92b4fd80-...
# 3   https://seismicatlas.org///entity?id=d89526c0-...
# 4   https://seismicatlas.org///entity?id=7998e3da-...
# 5   https://seismicatlas.org///entity?id=ed086012-...
# 6   https://seismicatlas.org///entity?id=c56c95c3-...
# 7   https://seismicatlas.org///entity?id=ba4bfcdc-...
# 8   https://seismicatlas.org///entity?id=6157758c-...
# 9   https://seismicatlas.org///entity?id=8f3d5439-...
# 10  https://seismicatlas.org///entity?id=922c7210-...
# 11  https://seismicatlas.org///entity?id=b047b8a3-...
# 12  https://seismicatlas.org///entity?id=055c90aa-...
# 13  https://seismicatlas.org///entity?id=45825358-...
# 14  https://seismicatlas.org///entity?id=f6c7b5b1-...
# 15  https://seismicatlas.org///entity?id=0ccd2827-...
# 16  https://seismicatlas.org///entity?id=958b5dd2-...
# 17  https://seismicatlas.org///entity?id=2adc03aa-...
# 18  https://seismicatlas.org///entity?id=2e8dcb70-...
# 19  https://seismicatlas.org///entity?id=f533bd43-...
# 20  https://seismicatlas.org///entity?id=0e66bd4e-...
# 21  https://seismicatlas.org///entity?id=95282284-...
# 22  https://seismicatlas.org///entity?id=e17d49c3-...
# 23  https://seismicatlas.org///entity?id=b8305487-...
# 24  https://seismicatlas.org///entity?id=3218bafa-...

# %%
def create_faults_url_docs(faults_url):
    
        # Download the url survey page
        response = requests.get(faults_url) 

        # Check successful response
        if response.status_code != 200:
            raise Exception('Failed to load page {}'.format(faults_url))

        # Parse using Beautiful soup
        faults_url_doc = BeautifulSoup(response.text, 'html.parser')
        
        return faults_url_doc

# %%
def get_faults_url_docs(faults_url_list):
    
    faults_url_docs = []
    for i in range(len(faults_url_list)):
        faults_url_docs.append(create_faults_url_docs(faults_url_list[i]))
    
    return faults_url_docs

# %%
faults_url_doc = get_faults_url_docs(faults_url)

# %%
len(faults_url_doc)
# Out:
# 16

# %%
def create_faults_sections(f_url_doc):

    faults_content_div = f_url_doc.find('div', class_='content')
    faults_sections = faults_content_div.find_all('section')
    
    return faults_sections

# %%
faults_url_doc_0 = create_faults_sections(faults_url_doc[0])
faults_url_doc_1 = create_faults_sections(faults_url_doc[1])
faults_url_doc_2 = create_faults_sections(faults_url_doc[2])
faults_url_doc_3 = create_faults_sections(faults_url_doc[3])
faults_url_doc_4 = create_faults_sections(faults_url_doc[4])
faults_url_doc_5 = create_faults_sections(faults_url_doc[5])

# %%
len(faults_url_doc_3)
# Out:
# 25

# %%
faults_sections = []
faults_sections.append(faults_url_doc_0)
faults_sections.append(faults_url_doc_1)

# %%
faults_sections
# Out:
# [[<section>
#   <figure class="thumbnail"><a href="/entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad"><img alt="" class="img-responsive" src="/uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad">Crustal Structure, West Orkney Basin, imaged by MOIST</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-03-12</td>
#   </tr>
#   </tbody></table>
#   <p>An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17). </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139"><img alt="" class="img-responsive" src="/uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139">Deep structure - Outer Isles Fault - from WINCH 1 profile</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-03-12</td>
#   </tr>
#   </tbody></table>
#   <p>An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a"><img alt="" class="img-responsive" src="/uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a">Deep Structure - West Orkney Basin, imaged on ultradeep seismic</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-03-12</td>
#   </tr>
#   </tbody></table>
#   <p>An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W"). </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=d89526c0-b276-4815-98fb-e2f99515195f"><img alt="" class="img-responsive" src="/uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=d89526c0-b276-4815-98fb-e2f99515195f">Deep structure Western Orkney Basin - from GRID17 (SLAVE)</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-03-12</td>
#   </tr>
#   </tbody></table>
#   <p>Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=7998e3da-2a89-4835-8809-e659078811aa"><img alt="" class="img-responsive" src="/uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=7998e3da-2a89-4835-8809-e659078811aa">Inversion, North Sea</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-19</td>
#   </tr>
#   </tbody></table>
#   <p>An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0"><img alt="" class="img-responsive" src="/uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0">Interpreting a deepwater thrust system, offshore Namibia</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-18</td>
#   </tr>
#   </tbody></table>
#   <p>An interpretation of a deepwater thrust belt. See associated scene if you'd like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=c56c95c3-d872-4b51-88c1-0f05d39effeb"><img alt="" class="img-responsive" src="/uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=c56c95c3-d872-4b51-88c1-0f05d39effeb">Faults and graben (less VE version), offshore Tunisia</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-06</td>
#   </tr>
#   </tbody></table>
#   <p>A rather better representation of faults and graben structure, with less vertical exaggeration. See the alternate interpretation for comparison. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=ba4bfcdc-5596-45a2-a320-88622c9f49b3"><img alt="" class="img-responsive" src="/uploaded/image/201309/21916a9a-2153-4ed2-9d89-5d005f5bdea5.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=ba4bfcdc-5596-45a2-a320-88622c9f49b3">Seismic stratigraphy exercise</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Julien Moreau</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2013-09-12</td>
#   </tr>
#   </tbody></table>
#   <p>Correction of a seismic interpretation exercise I gave.
#   The interpretation is uniquely based on reflection termination picking which indicate bounding surfaces. No model is involved.
#   Colours between two successive bounding surfaces have no genetic meaning they only give a sort of chronology through the repetition of a colour cycle (blue, pink, green,yellow) .
#   The objective of the exer...</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=6157758c-059b-4efd-995b-1f0058a2473f"><img alt="" class="img-responsive" src="/uploaded/image/202102/aec6418e-052c-4295-b65c-b8c7e610ff7a.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=6157758c-059b-4efd-995b-1f0058a2473f">Closely spaced faults - and imaging issues, offshore NW Morocco</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>This and associated interpretation (annotated) shows array of "synthetic" normal faults offsetting high-frequrency reflectors (probable contourites). </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=8f3d5439-6dc2-4c68-9664-e6839b496277"><img alt="" class="img-responsive" src="/uploaded/image/200908/4be2aa3a-a452-4bc0-bc90-f4e6524370a9.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=8f3d5439-6dc2-4c68-9664-e6839b496277">A high resolution version of the thrust belt, Namibia</a></span>
#   <span class="label label-scene">Scene</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2009-08-17</td>
#   </tr>
#   </tbody></table>
#   <p>High quality seismic reflection data reveal thrust and fold structural geometry offshore Namibia. The lack of image distortion and amplitude variations associated with structures indicates a generally simple seismic velocity structure that is a function of depth rather than stratigraphy. Note the preservation of amplitude up to the thrust cut-offs, with almost no loss in data quality....</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=922c7210-5e4a-4945-8bea-8fa95574364b"><img alt="" class="img-responsive" src="/uploaded/image/202001/462e8987-c4d2-493c-b77e-c60c0be9dd62.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=922c7210-5e4a-4945-8bea-8fa95574364b">The Moray Firth exercise interp annotated </a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2020-01-20</td>
#   </tr>
#   </tbody></table>
#   <p>This is the annotated version - with labelled megasequences and selected structures. Note that the boxed area (R side) is considered to have a high uncertainty - stemming from problems correlating stratal reflectors which are rather discontinuous here. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=b047b8a3-26ff-4198-ba0c-ea8fb418c524"><img alt="" class="img-responsive" src="/uploaded/image/202102/42954b88-dd40-49db-9621-f324257078f6.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=b047b8a3-26ff-4198-ba0c-ea8fb418c524">Interpretation solution to exercise - profile 29. </a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Interpretation (solution) to interpretation exercise (see clean image). The DOCS AND LINKS HERE has a step-wise pdf solution. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=055c90aa-f84c-449a-8f25-ca6581235e7d"><img alt="" class="img-responsive" src="/uploaded/image/202102/704bc1b9-0922-4556-9e8f-92ce870076a3.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=055c90aa-f84c-449a-8f25-ca6581235e7d">Faults and graben structure, offshore Tunisia</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-06</td>
#   </tr>
#   </tbody></table>
#   <p>This interpretation shows faults continuing to depth. The fault geometries on the right are obscured by migration and fault-shadowing artifacts. Note the scale - interpretation (less VE) version gives a more "realistic representation of basin structure. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=45825358-bfaa-41b9-aa4d-20d413d7ffcd"><img alt="" class="img-responsive" src="/uploaded/image/202102/10317df6-a715-4a48-b4e6-bc3e9e67d060.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=45825358-bfaa-41b9-aa4d-20d413d7ffcd">Imaging issues on the Apulian fault</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Apulian fault scarp - the seabed expression of a normal fault. The interpretation shows the image distortions that result - with dimming a migration problems in both the hangingwall and footwall. The image has very high (&gt; x5) vertical exaggeration of the seabed. See the alternate interpretation for a more realistic display. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=f6c7b5b1-f344-4b95-b1a7-8032e50e8dba"><img alt="" class="img-responsive" src="/uploaded/image/202102/e9a2f32e-be00-4448-bd67-d94ecae41727.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=f6c7b5b1-f344-4b95-b1a7-8032e50e8dba">Faults in shallow section of the Inner Moray Firth</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>An interpretation of faults and stratal reflectors. The clean version is set up as an interpretation exercise.</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=0ccd2827-2d7e-4d65-8f65-dc1dba410ccc"><img alt="" class="img-responsive" src="/uploaded/image/202102/a2649f5d-bdb4-4d8a-94ca-d0b79e9d9421.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=0ccd2827-2d7e-4d65-8f65-dc1dba410ccc">"regional" constructed for profile 29.</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Part of a solution to an interpretation exercise (see docs and links in clean version for task). This shows a "regional" on the yellow horizon that indicates the underlying structure is contractional. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=958b5dd2-97e6-4a41-93be-3d431417c2be"><img alt="" class="img-responsive" src="/uploaded/image/200802/6fe5069a-ea11-4ffc-b6e4-2fdf5f6bcf28.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=958b5dd2-97e6-4a41-93be-3d431417c2be">DW Niger delta fold - profile N29</a></span>
#   <span class="label label-scene">Scene</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>4</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2008-02-11</td>
#   </tr>
#   </tbody></table>
#   <p>Fore-thrust structure from the deep water Western Niger Delta. SEE DOCS &amp; LINKS FOR INTERPRETATION EXERCISE.
#
#   </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=2adc03aa-62f7-436e-9e3c-1951214cfb7e"><img alt="" class="img-responsive" src="/uploaded/image/202102/f1c6b095-51a5-4fb7-b5b1-d6ef25e37bd8.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=2adc03aa-62f7-436e-9e3c-1951214cfb7e">Rotational faulted minibasins, offshore Morocco</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Listric normal faults with growth strata formed above a mobile substrate (salt) </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=2e8dcb70-6282-49fe-b6ed-b9a117637771"><img alt="" class="img-responsive" src="/uploaded/image/202102/3cefee84-7033-4ed4-848e-83d3fa259cd7.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=2e8dcb70-6282-49fe-b6ed-b9a117637771">Normal faults, offshore Tunisia</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Normal faults interpreted for parts of the image. Note vertical scale - implies significant vertical exaggeration. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=f533bd43-b82f-4d4f-98d4-c3a3be180045"><img alt="" class="img-responsive" src="/uploaded/image/202102/91bd7827-8b8a-4320-bbbf-02a9d8ab6731.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=f533bd43-b82f-4d4f-98d4-c3a3be180045">Moray Firth Fault Zone 2 - interpreted with high VE</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Various imaging issues associated with this example - including a weak sea-bottom multiple that obscures the shallow structure of the fault block. Further imaging issues arise here as more lithified strata are on the seabed (hence higher amplitude sea bottom reflector) which impedes energy penetration. Additional structural complexity (addition faults?) reduce image quality (migration...</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=0e66bd4e-809b-4ca7-8003-fdb2708e0d93"><img alt="" class="img-responsive" src="/uploaded/image/202102/fbf8e47a-66b6-44b8-8126-44bbeb149077.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=0e66bd4e-809b-4ca7-8003-fdb2708e0d93">Moray Fault Zone 2 - low VE</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>A normal fault zone - with some identified imaging issues. Note too the hangingwall synform - presumably caused by distributed normal shear (breached tip-line folding).</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=95282284-bce7-44f8-b75d-8d5ba443d97e"><img alt="" class="img-responsive" src="/uploaded/image/202102/e3ef9772-7452-4b51-a200-ed61c802fb92.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=95282284-bce7-44f8-b75d-8d5ba443d97e">Faulting at the limit of seismic resolution, offshore NW Morocco.</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>See also annotated version. Faults in ?contourites  The faults are represented variably with depth as frequency and amplitude of reflectors vary. Do the complex patterns to R of section represent closely spaced faults (i.e. real geological deformation) or seismic noise (or both!). The bright, inclined reflectors - are these remobiilsed sand - (sandstone injections) along fault planes,...</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=e17d49c3-8ac1-4580-b0f4-657942d678bf"><img alt="" class="img-responsive" src="/uploaded/image/202102/0fb92504-62e5-458e-b943-8fc0d224830a.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=e17d49c3-8ac1-4580-b0f4-657942d678bf">Offshore Apulian fault scarp - less VE</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>An approximated representation of the offshore scarp on the Apulian fault, with rather little vertical exaggeration. See alternative interpretation for imaging issues. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=b8305487-9a32-476e-b1cd-3c4d004276d5"><img alt="" class="img-responsive" src="/uploaded/image/202102/3d9da7c8-0633-4349-909a-8a8aa39847d6.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=b8305487-9a32-476e-b1cd-3c4d004276d5">Offshore Apulian fault scarp</a></span>
#   <span class="label label-scene">Scene</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>2</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Seabed escarpment along the offshore Apulian fault. Very high vertical exaggeration... see interpretations... </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=3218bafa-1b27-42a8-bff9-13b6bd2a9589"><img alt="" class="img-responsive" src="/uploaded/image/201003/bb3710d6-e35d-445f-907f-e45fa065c996.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=3218bafa-1b27-42a8-bff9-13b6bd2a9589">Visualising seismic data in 3D - Gulf of Mexico 1, West Cameron 1</a></span>
#   <span class="label label-regional">Regional Project</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Alan Roberts</td>
#   </tr>
#   <tr>
#   <th>Scenes:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2010-03-05</td>
#   </tr>
#   </tbody></table>
#   <p>This image shows two seismic probes, within the same 3D data volume, plus an interpreted horizon surface. The probe on the left is a variable amplitude display and normal fault traces can be seen on both vertical surfaces and on the horizontal time-slice. The probe on the right is a coherency display and the fault traces are particularly clear on the horizontal upper surface. The inte...</p>
#   </section>],
#  [<section>
#   <figure class="thumbnail"><a href="/entity?id=32815c40-d89b-434b-aa2c-faa7fbbb7d3b"><img alt="" class="img-responsive" src="/uploaded/image/202102/9fdfd225-fe8d-4b84-9eeb-b030ef944244.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=32815c40-d89b-434b-aa2c-faa7fbbb7d3b">Moray Fault zone 1 - interp with less VE</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Interpretation of normal fault with a more realistic display. Compare with the alternative display.... </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=d55e7ca8-c9cd-40e9-8d00-cca5401c9d5c"><img alt="" class="img-responsive" src="/uploaded/image/202102/c18d7549-4e7e-4180-8a6b-86d51421e06a.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=d55e7ca8-c9cd-40e9-8d00-cca5401c9d5c">Moray fault zone 1 - interp with high VE</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Fault zone in Inner Moray Firth interpreted with high vertical exaggeration. Compare with version with less VE. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=a0845332-4ec5-47a8-9737-51fece4c8d5c"><img alt="" class="img-responsive" src="/uploaded/image/200802/9a09fb57-2f4f-47f7-8863-dbe53bfa7100.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=a0845332-4ec5-47a8-9737-51fece4c8d5c">Inner Moray Firth profile 1</a></span>
#   <span class="label label-regional">Regional Project</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Scenes:</th>
#   <td>5</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2008-02-10</td>
#   </tr>
#   </tbody></table>
#   <p>Regional profile across the Inner Moray Firth, acquired by Fugro.
#
#
#   </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=89bc07bd-bb05-46df-8b17-9b9f7d189cb4"><img alt="" class="img-responsive" src="/uploaded/image/202102/a2807802-d0c5-4f80-bae9-d7b0c1e0f982.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=89bc07bd-bb05-46df-8b17-9b9f7d189cb4">Faulting at the limit of seismic resolution, offshore NW Morocco - annotated.</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Annotated version. Faults in ?contourites  The faults are represented variably with depth as frequency and amplitude of reflectors vary. Do the complex patterns to R of section represent closely spaced faults (i.e. real geological deformation) or seismic noise (or both!). The bright, inclined reflectors - are these remobiilsed sand - (sandstone injections) along fault planes, or seism...</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=5f770d8f-7169-463c-a3de-438cb437edc9"><img alt="" class="img-responsive" src="/uploaded/image/202102/1d3ff4a8-c61d-46f3-ab20-66dba5b89d0d.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=5f770d8f-7169-463c-a3de-438cb437edc9">Closely spaced faults - an imaging issues, offshore NW Morocco - annotated</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Annotated version highlighting imaging issues - associated with smearing across faults of high-amplitude reflectors, together with miss-ties at depth. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=a000b276-c1d2-4e24-87ff-08c64d81d0e1"><img alt="" class="img-responsive" src="/uploaded/image/202102/baf7bcdb-9f81-4482-918f-dbace235182f.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=a000b276-c1d2-4e24-87ff-08c64d81d0e1">Faults in overburden to mobile salt, offshore NW Morocco</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Growth strata in hangingwall to fault above mobile salt - a minibasin margin. These strata are inferred to be contourites. The associated scenes show details from this - for discussion of minor fault patterns. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=af3d0cb3-1afb-4b12-b005-3cca1d5f829e"><img alt="" class="img-responsive" src="/uploaded/image/202102/17a7ffb3-90d7-48e6-aa52-a6a7d097b5ad.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=af3d0cb3-1afb-4b12-b005-3cca1d5f829e">Deformation above mobile substrate - offshore Morocco</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2021-02-01</td>
#   </tr>
#   </tbody></table>
#   <p>Although the substrate is poorly-imaged, the geometry of shallow strata, represented by the high-frequency reflector series, is clear. These strata are probably contourites. The associated scenes (via the Regional project) show stunning fault geometries...</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=d41c9781-cddd-41b0-950a-27fec1313d94"><img alt="" class="img-responsive" src="/uploaded/image/202010/e6296833-18d2-4792-93ac-37e0a6f58702.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=d41c9781-cddd-41b0-950a-27fec1313d94">Constructing regionals: Pelagian Shelf</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2020-10-12</td>
#   </tr>
#   </tbody></table>
#   <p>Constructing a "regional" to assist in the interpretation of structural style - in this case normal faults. See outline of workflow in "docs and links" - including link to a video on "regionals" </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=4cc4ef98-c4e7-4554-8ade-d826de2c66e9"><img alt="" class="img-responsive" src="/uploaded/image/200805/c0431b0f-c0a1-438f-ab34-3715bb47e717.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=4cc4ef98-c4e7-4554-8ade-d826de2c66e9">Triangle zone model for Mackenzie mountain front for AMOCO060-91-10</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Adriana Taborda, Deborah Spratt</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2008-05-15</td>
#   </tr>
#   </tbody></table>
#   <p>The front of the northern Mackenzie Mountains interpreted as a classic triangle zone (beneath the Peel Plateau). The upper detachment is bedding parallel in the shales of the Upper Devonian Imperial Formation.
#
#
#   </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=b619998b-6302-4d80-a97a-f275adaefb62"><img alt="" class="img-responsive" src="/uploaded/image/202001/e5b0a332-7fc4-405d-9a9b-ebb803efa936.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=b619998b-6302-4d80-a97a-f275adaefb62">Moray Firth ex interp with geology</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2020-01-20</td>
#   </tr>
#   </tbody></table>
#   <p>This is an interpretation - fairly basic, picking some main reflectors to illustrate megasequences - see annotated version for further explanation</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=5c98887c-ae70-4125-8ac1-e37d6091074e"><img alt="" class="img-responsive" src="/uploaded/image/202001/761591fb-2db8-49fa-b258-4df7ff25c8a7.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=5c98887c-ae70-4125-8ac1-e37d6091074e">Mud volcano DW Niger delta annotated</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2020-01-20</td>
#   </tr>
#   </tbody></table>
#   <p>This annotated version highlights various amplitude anomalies likely to represent hydrocarbons. They include a bottom simulating reflector representing gas hydrates and some bright spots deeper in the structure that could be DHIs - migrated gas. The footwall (R side) of the structure is uninterpreted. Note the thick growth sequence charting amplification of the anticline (in semi-tran...</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=640677ad-34c0-4f0f-b2a3-28f11978524c"><img alt="" class="img-responsive" src="/uploaded/image/202001/ffdbd14d-d188-49c9-8998-507f15becc54.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=640677ad-34c0-4f0f-b2a3-28f11978524c">mud volcano DW Nigeria</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2020-01-20</td>
#   </tr>
#   </tbody></table>
#   <p>Basic geological picks for the anticline in DW Niger delta - illustrating the growth strata, a thin veneer of post-kinematic strata. The anticline is punctured by mobile mud - that has erupted as a mud-volcano. </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=6f7b806a-670f-473b-8c1d-ba40f1d619c2"><img alt="" class="img-responsive" src="/uploaded/image/200802/a984c1b8-112f-4d65-859b-1a1a49af2ae0.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=6f7b806a-670f-473b-8c1d-ba40f1d619c2">Western Niger Delta - profile of whole slope</a></span>
#   <span class="label label-regional">Regional Project</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Richard Morgan</td>
#   </tr>
#   <tr>
#   <th>Scenes:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>2</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2008-02-04</td>
#   </tr>
#   </tbody></table>
#   <p>A regional section down the Western Niger delta - the whole slope. This profile appeared in Morgan, R. (2006) The Niger delta: an active passive margin. Geo Expro 4 (5), p. 36
#
#
#   </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=80b53eda-4910-44db-87ef-6cbcb51f9fc3"><img alt="" class="img-responsive" src="/uploaded/image/200908/4a55c6f4-2990-49be-ae44-438a537075ef.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=80b53eda-4910-44db-87ef-6cbcb51f9fc3">All Namibian Margin Balancing - overview</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2009-08-17</td>
#   </tr>
#   </tbody></table>
#   <p>This interpreted section shows arbitrary picks and designation of units in the extensional domain, and two markers in the contractional domain. Note that the vertical exaggeration is approximately 7:1 . assuming a mean seismic velocity of 2.7 km/s.  See the scenes for this image for further comments.
#
#   </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=20fa8264-2a16-466f-bb12-cc39a88518ce"><img alt="" class="img-responsive" src="/uploaded/image/201001/40343702-355c-485c-bbf3-67add221c681.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=20fa8264-2a16-466f-bb12-cc39a88518ce">FIRE 2 interpretation</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Taija Torvela</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2010-01-12</td>
#   </tr>
#   </tbody></table>
#   <p>Interpretation by Nironen et al. (2006). The FIRE 2 (and 2A) deep seismic reflection profiles were designed to study the relationships between the arc complexes of western and southern Finland and their internal structures (see docs &amp; links for a location map). FIRE 2 begins in the central part of the arc complex of western Finland in the north, within the Central Finland Granitoid Co...</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=4b75cded-8d3c-423d-a35d-e47a7f1bc41a"><img alt="" class="img-responsive" src="/uploaded/image/201605/05e0db64-7841-4747-9f41-c6b4e474294a.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=4b75cded-8d3c-423d-a35d-e47a7f1bc41a">DRUM filtered 2</a></span>
#   <span class="label label-regional">Regional Project</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Taija Torvela</td>
#   </tr>
#   <tr>
#   <th>Scenes:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>1</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2016-05-02</td>
#   </tr>
#   </tbody></table>
#   <p>The original seismic is filtered with 8x8 (trace x sample) dip-steered median filter of Opendtect with a maximum seismic dip of c. 40 degrees, this reduces 1D noise and also removes some steep coherent noise while enhancing signal continuity. This filtered seismic is then overlain with the cosine of phase attribute of the dip-steered data, in order to enhance the signal geometries fur...</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=47bb8df6-1985-4104-9fe1-1b364b72ee8a"><img alt="" class="img-responsive" src="/uploaded/image/200802/00fc8fcb-69e5-47af-ab13-8ba488cb2906.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=47bb8df6-1985-4104-9fe1-1b364b72ee8a">Inner Moray Firth profile 4</a></span>
#   <span class="label label-regional">Regional Project</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Scenes:</th>
#   <td>6</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>1</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2008-02-08</td>
#   </tr>
#   </tbody></table>
#   <p>A regional line across the Inner Moray Firth, Northern North Sea. The line is oriented NW (L), SE (R) and is displayed in TWT.
#
#
#   </p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=e5ba8d3c-84e1-4ef7-a154-7788ed483e8f"><img alt="" class="img-responsive" src="/uploaded/image/201501/cbaf60dc-115c-4015-88c8-bfeafd39bbbb.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=e5ba8d3c-84e1-4ef7-a154-7788ed483e8f">Architecture and image characteristics of a normal fault - Inner Moray Firth</a></span>
#   <span class="label label-interpretation">Interpretation</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Rob Butler</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2015-01-28</td>
#   </tr>
#   </tbody></table>
#   <p>These interpretations display a correlation of units across the fault zone - which has synthetic splays and an offset relay structure at depth. The growth strata are chiefly of upper Jurassic in age - with the deepest identified unit par of the middle Jurassic (locally) pre-rift stratigraphy. The annotations identify some "typical" characteristics of faults imaged in 2D seismic data. ...</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=44660707-f98d-4745-8f88-09f13f07eeea"><img alt="" class="img-responsive" src="/uploaded/image/201610/0aca3826-9d4f-4126-bf8a-0b40b2e96550.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=44660707-f98d-4745-8f88-09f13f07eeea">S83-56</a></span>
#   <span class="label label-regional">Regional Project</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Taija Torvela</td>
#   </tr>
#   <tr>
#   <th>Scenes:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2016-10-17</td>
#   </tr>
#   </tbody></table>
#   <p>This image is used in the interpretation by Jimenez-Bonilla et al. (2017, Tectonics) of the internal structure and basement properties of the external Betics FTB from Sierras Subbeticas NW-wards to the Guadalquivir Basin. Please see the publication for interpretation and discussion. Location map and paper link in the docs and links section of this image.</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=3ba70da9-ce2c-42ff-9cbb-dc66c703490d"><img alt="" class="img-responsive" src="/uploaded/image/201610/dae08e23-f906-47d5-a392-bb2d6adaa83f.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=3ba70da9-ce2c-42ff-9cbb-dc66c703490d">S83-50</a></span>
#   <span class="label label-regional">Regional Project</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Taija Torvela</td>
#   </tr>
#   <tr>
#   <th>Scenes:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2016-10-17</td>
#   </tr>
#   </tbody></table>
#   <p>This image is used in the interpretation by Jimenez-Bonilla et al. (2017, Tectonics) of the internal structure and basement properties of the external Betics FTB from Sierras Subbeticas NW-wards to the Guadalquivir Basin. Please see the publication for interpretation and discussion. Location map and paper link in the docs and links section of this image.</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=506d2bef-4f6c-4ffb-879f-9109a7bd9606"><img alt="" class="img-responsive" src="/uploaded/image/201610/6ec467a1-4889-4734-bd2e-3e941c0bf878.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=506d2bef-4f6c-4ffb-879f-9109a7bd9606">S83-48</a></span>
#   <span class="label label-regional">Regional Project</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Taija Torvela</td>
#   </tr>
#   <tr>
#   <th>Scenes:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2016-10-17</td>
#   </tr>
#   </tbody></table>
#   <p>This image is used in the interpretation by Jimenez-Bonilla et al. (2017, Tectonics) of the internal structure and basement properties of the external Betics FTB from Sierras Subbeticas NW-wards to the Guadalquivir Basin. Please see the publication for interpretation and discussion. Location map and paper link in the docs and links section of this image.</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=abb870a0-8032-4c36-9c97-9ba144f21ede"><img alt="" class="img-responsive" src="/uploaded/image/201610/af294b21-134d-49de-a7d5-7c927b4a771b.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=abb870a0-8032-4c36-9c97-9ba144f21ede">S83-40</a></span>
#   <span class="label label-regional">Regional Project</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Taija Torvela</td>
#   </tr>
#   <tr>
#   <th>Scenes:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2016-10-17</td>
#   </tr>
#   </tbody></table>
#   <p>This image is used in the interpretation by Jimenez-Bonilla et al. (2017, Tectonics) of the internal structure and basement properties of the external Betics FTB from Sierras Subbeticas NW-wards to the Guadalquivir Basin. Please see the publication for interpretation and discussion. Location map and paper link in the docs and links section of this image.</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=42c61aa8-d680-4df0-9191-52b2a4a1d5fe"><img alt="" class="img-responsive" src="/uploaded/image/201610/ee090505-695d-4bf5-8217-0ecff779379c.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=42c61aa8-d680-4df0-9191-52b2a4a1d5fe">BT-8A</a></span>
#   <span class="label label-regional">Regional Project</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Taija Torvela</td>
#   </tr>
#   <tr>
#   <th>Scenes:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2016-10-17</td>
#   </tr>
#   </tbody></table>
#   <p>This image is used in the interpretation by Jimenez-Bonilla et al. (2017, Tectonics) of the internal structure and basement properties of the external Betics FTB from Sierras Subbeticas NW-wards to the Guadalquivir Basin. Please see the publication for interpretation and discussion. Location map and paper link in the docs and links section of this image.</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=1081be5c-87ba-432e-b457-75730c5fd0dc"><img alt="" class="img-responsive" src="/uploaded/image/201610/b8c53f26-d1f9-4bd9-b5bc-6b67d2271b7b.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=1081be5c-87ba-432e-b457-75730c5fd0dc">AES84-21</a></span>
#   <span class="label label-regional">Regional Project</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Taija Torvela</td>
#   </tr>
#   <tr>
#   <th>Scenes:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2016-10-17</td>
#   </tr>
#   </tbody></table>
#   <p>This image is used in the interpretation by Jimenez-Bonilla et al. (2017, Tectonics) of the internal structure and basement properties of the external Betics FTB from Sierras Subbeticas NW-wards to the Guadalquivir Basin. Please see the publication for interpretation and discussion. Location map and paper link in the docs and links section of this image.</p>
#   </section>,
#   <section>
#   <figure class="thumbnail"><a href="/entity?id=257479da-9e2a-4ef9-a91a-612e2a9d4f2a"><img alt="" class="img-responsive" src="/uploaded/image/201610/a2379ea9-dd6b-4373-8a61-9da084df4b97.jpg"/></a></figure>
#   <h4>
#   <span><a href="/entity?id=257479da-9e2a-4ef9-a91a-612e2a9d4f2a">AES84-20</a></span>
#   <span class="label label-regional">Regional Project</span>
#   </h4>
#   <table class="summary">
#   <tbody><tr>
#   <th>VSA Author:</th>
#   <td>Taija Torvela</td>
#   </tr>
#   <tr>
#   <th>Scenes:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Interpretations:</th>
#   <td>0</td>
#   </tr>
#   <tr>
#   <th>Date Created:</th>
#   <td>2016-10-17</td>
#   </tr>
#   </tbody></table>
#   <p>This image is used in the interpretation by Jimenez-Bonilla et al. (2017, Tectonics) of the internal structure and basement properties of the external Betics FTB from Sierras Subbeticas NW-wards to the Guadalquivir Basin. Please see the publication for interpretation and discussion. Location map and paper link in the docs and links section of this image.</p>
#   </section>]]

# %%
faults_sections = []

for i in range(len(faults_url_doc)):
    faults_sections.append(create_faults_sections(faults_url_doc[i]))
    
    faults_sections

# %%
len(faults_sections)
# Out:
# 16

# %%
create_faults_sections(faults_url_doc[15])
# Out:
# [<section>
#  <figure class="thumbnail"><a href="/entity?id=0e1c2621-fdfb-4bf6-8e46-11c6d074c8ff"><img alt="" class="img-responsive" src="/uploaded/image/200802/13fd90b8-be40-4cbc-bbee-5bb82e666ea8.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=0e1c2621-fdfb-4bf6-8e46-11c6d074c8ff">DW Niger delta fold - profile N34 - interpreted</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-11</td>
#  </tr>
#  </tbody></table>
#  <p>Fore-thrust structure in the deep water western Niger delta. The simple thrust ramp at depth passes up-dip into a zone of distributed deformation that defines a trishear zone, contained as the fore-limb of the anticline.
#
#
#  </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=46332bc9-1654-4480-a0e4-8e255b5677f2"><img alt="" class="img-responsive" src="/uploaded/image/200802/ae384f6e-3eed-4ad9-8eb5-f1940af8afe4.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=46332bc9-1654-4480-a0e4-8e255b5677f2">DW Niger delta fold - profile N34</a></span>
#  <span class="label label-scene">Scene</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Interpretations:</th>
#  <td>2</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-11</td>
#  </tr>
#  </tbody></table>
#  <p>Fore-thrust structure in deep water Western Niger delta.
#
#
#  </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=ef7af92c-eff4-493b-a942-c5146e6ca093"><img alt="" class="img-responsive" src="/uploaded/image/200802/e8dab29b-7390-4f06-9aad-c894ff84c85f.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=ef7af92c-eff4-493b-a942-c5146e6ca093">DW Niger delta fold - profile N29 - annotated</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-11</td>
#  </tr>
#  </tbody></table>
#  <p>Anticline carried on a fore-thrust (down-slope verging) - deep water western Niger delta. At depth the thrust zone is marked by a series of soft-linked strands. These appear to collapse onto a single thrust surface up-dip that cuts into the synkinematic strata. An incipient trishear zone breaks into the hanging-wall which becomes more fully developed to the SE (see profile N34). Backt...</p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=c3f7a174-174c-4c55-ab3c-78157aaba851"><img alt="" class="img-responsive" src="/uploaded/image/200802/35cfb566-72f2-492e-b8f3-ad46e5d9700f.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=c3f7a174-174c-4c55-ab3c-78157aaba851">DW Niger delta fold - profile N20 - annotated</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-11</td>
#  </tr>
#  </tbody></table>
#  <p>Thrust-cored anticline from deep water western Niger delta. This is a similar structure to profile N18 but shows well developed bi-directional thrusting at depth (Agbada/Akata boundary. Both thrusts pass up-dip into trishear zones.
#
#
#  </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=c99f8ce7-b6f3-4e0a-9423-ddcc4d583f10"><img alt="" class="img-responsive" src="/uploaded/image/200802/5c979032-9430-4df2-8e0f-1c6c83064fcf.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=c99f8ce7-b6f3-4e0a-9423-ddcc4d583f10">DW Niger delta fold - profile N20</a></span>
#  <span class="label label-scene">Scene</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Interpretations:</th>
#  <td>2</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-11</td>
#  </tr>
#  </tbody></table>
#  <p>Triangle zone/pop-up structure in the deep water Western Niger Delta. Both thrusts pass upwards into trishear zones.
#
#
#  </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=9ac31868-ddc1-4727-91dd-d91a0b521495"><img alt="" class="img-responsive" src="/uploaded/image/200802/e5a0de95-f1ba-4ceb-b4a0-256051040eaa.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=9ac31868-ddc1-4727-91dd-d91a0b521495">Dutch graben margin profile 4</a></span>
#  <span class="label label-regional">Regional Project</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td></td>
#  </tr>
#  <tr>
#  <th>Organization:</th>
#  <td>FUGRO</td>
#  </tr>
#  <tr>
#  <th>Scenes:</th>
#  <td>0</td>
#  </tr>
#  <tr>
#  <th>Interpretations:</th>
#  <td>0</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-11</td>
#  </tr>
#  </tbody></table>
#  <p>2D seismic profile through the eastern margin of the Dutch Graben - illustrating major unconformities and minor faulting.
#
#
#  </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=d14186e4-c59a-40be-b8bc-1cc4fb040f0c"><img alt="" class="img-responsive" src="/uploaded/image/200802/830e38c3-4050-42f6-9f88-2d36f5206e4f.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=d14186e4-c59a-40be-b8bc-1cc4fb040f0c">Dutch graben margin - profile 2</a></span>
#  <span class="label label-regional">Regional Project</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td></td>
#  </tr>
#  <tr>
#  <th>Organization:</th>
#  <td>FUGRO</td>
#  </tr>
#  <tr>
#  <th>Scenes:</th>
#  <td>0</td>
#  </tr>
#  <tr>
#  <th>Interpretations:</th>
#  <td>0</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-11</td>
#  </tr>
#  </tbody></table>
#  <p>2D seismic profile across part of the eatern margin of the Dutch graben, southern North Sea.    The prominent salt dome/diapir has localised faulting in the Tertiary section . Note salt weld to lefdt of dome.
#
#
#  </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=026b91b3-c042-4f7b-802d-756a4613fa97"><img alt="" class="img-responsive" src="/uploaded/image/200802/35965a49-9afc-44a2-8e29-ed3bb5078e77.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=026b91b3-c042-4f7b-802d-756a4613fa97">Dutch graben margin - profile 1</a></span>
#  <span class="label label-regional">Regional Project</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td></td>
#  </tr>
#  <tr>
#  <th>Organization:</th>
#  <td>FUGRO</td>
#  </tr>
#  <tr>
#  <th>Scenes:</th>
#  <td>0</td>
#  </tr>
#  <tr>
#  <th>Interpretations:</th>
#  <td>1</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-11</td>
#  </tr>
#  </tbody></table>
#  <p>Regional profile through salt structures in the eastern part of the Dutch graben, southern North Sea.
#
#  </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=d358bc3a-37aa-4fd5-8670-a8ace2316de3"><img alt="" class="img-responsive" src="/uploaded/image/200802/18e01341-517c-4b7f-b8e6-36682562eb9d.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=d358bc3a-37aa-4fd5-8670-a8ace2316de3">DW Niger delta fold - profile N18 - annotated</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-11</td>
#  </tr>
#  </tbody></table>
#  <p>Thrust-cored anticline in the deep water Western Niger delta. Although the overall fold is asymmetric and verges upslope, in the same sense as the main back-thrust, at depth there is forethrusting. Conventional thrust models would predict that the back and forethrusts would splay from the same point (a so-called "singularity". Clearly here they do not.
#               ...</p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=edf8688f-90c7-4ee9-9ac9-2c21543d2478"><img alt="" class="img-responsive" src="/uploaded/image/200802/3643abf7-91c6-4c7c-bf07-0b44f9508f1d.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=edf8688f-90c7-4ee9-9ac9-2c21543d2478">DW Niger delta fold - profile N07 - interpreted</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-11</td>
#  </tr>
#  </tbody></table>
#  <p>Back-thrust structure (verging up regional slope). Note that the main thrust cuts into the footwall, away from the related hanging-wall anticline. It branches from a thrust/trishear zone. At depth there is little indication of thrusting at the Akarta/Agbada boundary. Perhaps contraction is accommodated by distributed shortening.
#
#
#  </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=b4b5a4a1-db18-4ded-bbf4-5b9d81f97bec"><img alt="" class="img-responsive" src="/uploaded/image/200802/2452f753-2791-4254-a9e7-d5d8ad3c76ef.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=b4b5a4a1-db18-4ded-bbf4-5b9d81f97bec">DW Niger delta fold - profile N18</a></span>
#  <span class="label label-scene">Scene</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Interpretations:</th>
#  <td>2</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-11</td>
#  </tr>
#  </tbody></table>
#  <p>Nearing the transfer zone along the anticline as the structure changes from a back-thrust (in NE) to a fore-thrust (in the SW). Both vergences are evident at depth - along the Agbada/Akata transition.
#
#
#  </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=ea764d8b-b228-4a52-8008-09ec350d4c81"><img alt="" class="img-responsive" src="/uploaded/image/200802/be1dc1f1-427e-4018-baec-eabe2fedf845.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=ea764d8b-b228-4a52-8008-09ec350d4c81">Example 1: fault systems in the Inner Moray Firth</a></span>
#  <span class="label label-scene">Scene</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Interpretations:</th>
#  <td>0</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-08</td>
#  </tr>
#  </tbody></table>
#  <p>Arrays of intra-basinal normal faults from Inner Moray Firth, regional line 4.     NW (L) to SE (R).
#
#
#  </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=bea7b151-adad-4357-8352-43532b151226"><img alt="" class="img-responsive" src="/uploaded/image/200802/627ef9f1-96d6-45d0-9116-854c83648434.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=bea7b151-adad-4357-8352-43532b151226">DW Nigeria profile 1 - block colour</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-04</td>
#  </tr>
#  </tbody></table>
#  <p>Interprted sectiion through the toe thrust system, deep water Niger delta. Note both down-slop (fore) and upslope (back-) thrusts.
#
#
#  </p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=f3b921ab-d718-403a-98ff-c6b8ffa01aa8"><img alt="" class="img-responsive" src="/uploaded/image/200802/aa96b9e0-d6ea-4647-9cbf-d6a0460ea8f5.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=f3b921ab-d718-403a-98ff-c6b8ffa01aa8">BIRPS - DRUM -Flack &amp; Warner 1990 interpretation</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Estelle Mortimer</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-05</td>
#  </tr>
#  </tbody></table>
#  <p>In this interpretation (after Flack and Warner, 1990) the presence of Mesozoic basins in and normal faults in the upper  the presence of Mesozoic basins in and normal faults in the upper 5 seconds of the DRUM profile are clearly identified. Permian and older sediments (possibly to Torridonian) could account for reflections down to 4 seconds in the basins – particularly in the North Le...</p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=210f0fc9-b2d4-44a7-8388-32fc564bbe7c"><img alt="" class="img-responsive" src="/uploaded/image/200802/c1b69d0c-d665-4d10-9fd2-a1c7926df121.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=210f0fc9-b2d4-44a7-8388-32fc564bbe7c">BIRPS- DRUM -McGeary &amp; Warner 1985 interpretation</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Estelle Mortimer</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-05</td>
#  </tr>
#  </tbody></table>
#  <p>This interpreted line drawing showing the principle high amplitude reflectors (after McGeary and Warner, 1985) and key structural elements and the position of the Moho (after McGeary and Warner, 1985; Morgan et al., 2000) in the DRUM profile from the BIRPS surveys. The line drawing identifies rotated half-graben blocks in the upper crust and reflective lower crust and Moho. Beneath th...</p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=c7fc4157-227f-4add-aea0-9f97960f355d"><img alt="" class="img-responsive" src="/uploaded/image/200802/ee442803-6df3-46d9-b267-cd353dcd5729.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=c7fc4157-227f-4add-aea0-9f97960f355d">Salt model Silverpit - interpreted</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>John Underhill</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-04</td>
#  </tr>
#  </tbody></table>
#  <p>In this interpretation of a seismic section that transects the centre of the Silverpit structure, the structural relief of the folding is clearly demonstrated as well as the coincidence between the location of synclines and the thinning of the Zechstein evaporates. The implication is that the Silverpit structure is one of a number of similar structures that resulted from the withdrawa...</p>
#  </section>,
#  <section>
#  <figure class="thumbnail"><a href="/entity?id=1725067e-04ff-4a5c-8020-acdd26b193f4"><img alt="" class="img-responsive" src="/uploaded/image/200802/5b27d519-5149-412c-8414-aa285f73fbca.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=1725067e-04ff-4a5c-8020-acdd26b193f4">DW Nigeria Profile 1 (V=H) linework</a></span>
#  <span class="label label-interpretation">Interpretation</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Rob Butler</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2008-02-04</td>
#  </tr>
#  </tbody></table>
#  <p></p>
#  </section>]

# %%
faults_url_divs = []

for i in range(len(faults_url_doc[10])):   
    
#     faults_url_sections.append(create_faults_sections(faults_url_doc[i]))
    
    faults_content_div = faults_url_doc[i].find_all('div', class_='content')
    #faults_sections = faults_content_div[.find_all('section')
    faults_url_divs.append(faults_content_div)
    
    faults_content_div

# %%
len(faults_content_div)
# Out:
# 1

# %%
faults_url_sections = []

for i in range(len(faults_content_div)):   
    
#     faults_url_sections.append(create_faults_sections(faults_url_doc[i]))
    
    #faults_content_div = faults_url_doc[i].find_all('div', class_='content')
    faults_sections = faults_content_div[i].find('section')
    faults_url_sections.append(faults_sections)
    
    faults_url_sections

# %%
len(faults_url_sections)
# Out:
# 1

# %%
faults_url_sections
# Out:
# [<section>
#  <figure class="thumbnail"><a href="/entity?id=afeba2b7-c281-4493-9dab-42f4256b49ea"><img alt="" class="img-responsive" src="/uploaded/image/201610/4f1d5216-5dd0-4cc2-94d7-b7a05b29a461.jpg"/></a></figure>
#  <h4>
#  <span><a href="/entity?id=afeba2b7-c281-4493-9dab-42f4256b49ea">AES84-16</a></span>
#  <span class="label label-regional">Regional Project</span>
#  </h4>
#  <table class="summary">
#  <tbody><tr>
#  <th>VSA Author:</th>
#  <td>Taija Torvela</td>
#  </tr>
#  <tr>
#  <th>Scenes:</th>
#  <td>0</td>
#  </tr>
#  <tr>
#  <th>Interpretations:</th>
#  <td>0</td>
#  </tr>
#  <tr>
#  <th>Date Created:</th>
#  <td>2016-10-17</td>
#  </tr>
#  </tbody></table>
#  <p>This image is used in the interpretation by Jimenez-Bonilla et al. (2017, Tectonics) of the internal structure and basement properties of the external Betics FTB from Sierras Subbeticas NW-wards to the Guadalquivir Basin. Please see the publication for interpretation and discussion. Location map and paper link in the docs and links section of this image.</p>
#  </section>]

# %%
def get_faults_sections(faults_url_doc):
    
    faults_url_sections = []
    for i in range(len(faults_url_doc)):
        faults_url_sections.append(create_faults_sections(faults_url_doc[i]))
    
    return faults_url_sections

# %%
# faults_sections_data = []
# for section in faults_sections:
#     faults_sections_data.append(parse_faults_section(section))
    
#     print(faults_sections_data)

# %%
faults_sections_data_all = get_faults_sections(faults_url_doc)

# %%
len(faults_sections_data_all)
# Out:
# 16

# %%
faults_sections_data_all[15][16]
# Out:
# <section>
# <figure class="thumbnail"><a href="/entity?id=1725067e-04ff-4a5c-8020-acdd26b193f4"><img alt="" class="img-responsive" src="/uploaded/image/200802/5b27d519-5149-412c-8414-aa285f73fbca.jpg"/></a></figure>
# <h4>
# <span><a href="/entity?id=1725067e-04ff-4a5c-8020-acdd26b193f4">DW Nigeria Profile 1 (V=H) linework</a></span>
# <span class="label label-interpretation">Interpretation</span>
# </h4>
# <table class="summary">
# <tbody><tr>
# <th>VSA Author:</th>
# <td>Rob Butler</td>
# </tr>
# <tr>
# <th>Date Created:</th>
# <td>2008-02-04</td>
# </tr>
# </tbody></table>
# <p></p>
# </section>

# %%
flts_sections_data = []

for i in range(len(faults_sections_data_all)):
           for j in range(0, 25):
               flts_sections_data.append(parse_faults_section(faults_sections_data_all[i][j]))

           print(flts_sections_data)
# Out:
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# [{'Title': 'Crustal Structure, West Orkney Basin, imaged by MOIST', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/ba8eb087-bbce-4efe-903f-f5b5fd69509f.jpg', 'Description': 'An interpretation of the first profile acquired by the BIRPS programme in 1981: MOIST. It images the crustal structure of the West Orkney Basin area, offshore N Scotland. Compare with interpretations of other BIRPS profiles that were acquired over the following years, with increasingly effective acquisition and processing strategies (WINCH-1, DRUM and GRID-17).', 'Info url': 'https://seismicatlas.org///entity?id=cad7a17f-d9c3-430e-83c2-7731247529ad'}, {'Title': 'Deep structure - Outer Isles Fault - from WINCH 1 profile', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/9f048ab2-7295-41cd-8224-68a1527c2a5e.jpg', 'Description': "An interpretation of BIRPS' WINCH-1 profile (from 1982) that images the crust crust around the Outer Isles Fault, offshore N Scotland - along with the enigmatic sub-Moho structure.", 'Info url': 'https://seismicatlas.org///entity?id=5daf55c7-7d75-47e9-9efc-ec65076b8139'}, {'Title': 'Deep Structure - West Orkney Basin, imaged on ultradeep seismic', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/c50021dd-96b9-4612-af7f-0d1b89d31fb2.jpg', 'Description': 'An interpretation of the BIRPS DRUM line (from 1984) - showing the crustal structure (rift basins developed across the Caledonian deformation front, offshore N Scotland) and the underlying, still enigmatic, sub-Moho reflective zones (Flannan and "W").', 'Info url': 'https://seismicatlas.org///entity?id=92b4fd80-b159-4e97-b77b-6cdc412b017a'}, {'Title': 'Deep structure Western Orkney Basin - from GRID17 (SLAVE)', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-03-12', 'Image url': 'https://seismicatlas.org///uploaded/image/202103/2f899bc1-9174-4c5d-8469-f53968b42585.jpg', 'Description': 'Interpretation of the GRID 17 profile (aka Synthetic Large-Aperture Velocity Experiment) through the West Orkney Basin, offshore N Scotland, that images the crustal structure (including the Outer Isles fault zone) and the enigmatic reflectors in the upper mantle (Flannan, "W")', 'Info url': 'https://seismicatlas.org///entity?id=d89526c0-b276-4815-98fb-e2f99515195f'}, {'Title': 'Inversion, North Sea', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-19', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/cf6b24d7-5944-4c6c-b632-ceeaf6649fa8.jpg', 'Description': 'An interpretation of an inversion structure from the North Sea, using the "regional" concept. Two regionals are shown, together with the relative motion of their stratal surfaces.', 'Info url': 'https://seismicatlas.org///entity?id=7998e3da-2a89-4835-8809-e659078811aa'}, {'Title': 'Interpreting a deepwater thrust system, offshore Namibia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-18', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/53bdb54b-d4c1-4172-a074-69d8aee76d5b.jpg', 'Description': 'An interpretation of a deepwater thrust belt. See associated scene if you\'d like to use this to run a simple seismic interpretation exercise. The clean "scene" has, via its docs and links, a pdf that goes through an interpretation workflow.', 'Info url': 'https://seismicatlas.org///entity?id=ed086012-c81d-48fc-a71f-bc880b50d2e0'}, {'Title': 'Faults and graben (less VE version), offshore Tunisia', 'Data Type': 'Interpretation', 'Author': 'Rob Butler', 'Date': '2021-02-06', 'Image url': 'https://seismicatlas.org///uploaded/image/202102/9309d390-5ddd-4173-b885-a1bde84f9d07.jpg', 'Description': 'A rather better representation of faults and graben structure, with less vertical exaggeration. See  ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-641f9942e93c> in <module>
#       3 for i in range(len(faults_sections_data_all)):
#       4            for j in range(0, 25):
# ----> 5                flts_sections_data.append(parse_faults_section(faults_sections_data_all[i][j]))
#       6
#       7            print(flts_sections_data)
#
# IndexError: list index out of range

# %%
len(flts_sections_data)
# Out:
# 392

# %%
faults_sections_all_df = pd.DataFrame(flts_sections_data)

# %%
faults_sections_all_df
# Out:
#                                                  Title       Data Type  \
# 0    Crustal Structure, West Orkney Basin, imaged b...  Interpretation
# 1    Deep structure - Outer Isles Fault - from WINC...  Interpretation
# 2    Deep Structure - West Orkney Basin, imaged on ...  Interpretation
# 3    Deep structure Western Orkney Basin - from GRI...  Interpretation
# 4                                 Inversion, North Sea  Interpretation
# ..                                                 ...             ...
# 387                DW Nigeria profile 1 - block colour  Interpretation
# 388   BIRPS - DRUM -Flack & Warner 1990 interpretation  Interpretation
# 389  BIRPS- DRUM -McGeary & Warner 1985 interpretation  Interpretation
# 390                 Salt model Silverpit - interpreted  Interpretation
# 391                DW Nigeria Profile 1 (V=H) linework  Interpretation
#
#                Author        Date  \
# 0          Rob Butler  2021-03-12
# 1          Rob Butler  2021-03-12
# 2          Rob Butler  2021-03-12
# 3          Rob Butler  2021-03-12
# 4          Rob Butler  2021-02-19
# ..                ...         ...
# 387        Rob Butler  2008-02-04
# 388  Estelle Mortimer  2008-02-05
# 389  Estelle Mortimer  2008-02-05
# 390    John Underhill  2008-02-04
# 391        Rob Butler  2008-02-04
#
#                                              Image url  \
# 0    https://seismicatlas.org///uploaded/image/2021...
# 1    https://seismicatlas.org///uploaded/image/2021...
# 2    https://seismicatlas.org///uploaded/image/2021...
# 3    https://seismicatlas.org///uploaded/image/2021...
# 4    https://seismicatlas.org///uploaded/image/2021...
# ..                                                 ...
# 387  https://seismicatlas.org///uploaded/image/2008...
# 388  https://seismicatlas.org///uploaded/image/2008...
# 389  https://seismicatlas.org///uploaded/image/2008...
# 390  https://seismicatlas.org///uploaded/image/2008...
# 391  https://seismicatlas.org///uploaded/image/2008...
#
#                                            Description  \
# 0    An interpretation of the first profile acquire...
# 1    An interpretation of BIRPS' WINCH-1 profile (f...
# 2    An interpretation of the BIRPS DRUM line (from...
# 3    Interpretation of the GRID 17 profile (aka Syn...
# 4    An interpretation of an inversion structure fr...
# ..                                                 ...
# 387  Interprted sectiion through the toe thrust sys...
# 388  In this interpretation (after Flack and Warner...
# 389  This interpreted line drawing showing the prin...
# 390  In this interpretation of a seismic section th...
# 391
#
#                                               Info url
# 0    https://seismicatlas.org///entity?id=cad7a17f-...
# 1    https://seismicatlas.org///entity?id=5daf55c7-...
# 2    https://seismicatlas.org///entity?id=92b4fd80-...
# 3    https://seismicatlas.org///entity?id=d89526c0-...
# 4    https://seismicatlas.org///entity?id=7998e3da-...
# ..                                                 ...
# 387  https://seismicatlas.org///entity?id=bea7b151-...
# 388  https://seismicatlas.org///entity?id=f3b921ab-...
# 389  https://seismicatlas.org///entity?id=210f0fc9-...
# 390  https://seismicatlas.org///entity?id=c7fc4157-...
# 391  https://seismicatlas.org///entity?id=1725067e-...
#
# [392 rows x 7 columns]

# %%
faults_sections_df.to_csv('faults_images_data.csv', index=None)

# %%
# Execute this to save new versions of the notebook

jovian.commit(project="seismic-data-processing")
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "ramysaleem/seismic-data-processing" on https://jovian.ai
# [jovian] Uploading notebook..
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.ai/ramysaleem/seismic-data-processing
# 'https://jovian.ai/ramysaleem/seismic-data-processing'
